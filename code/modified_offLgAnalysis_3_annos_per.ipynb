# %%
### basic imports, read in data file
import csv, statistics, random
import nltk
from nltk import agreement
data = []
with open('all_annos_dec19.csv') as infile:
    csvreader = csv.reader(infile)
    for row in csvreader:
        data.append(row)

# %%
### check the data/header line
print(data[:2])
print(len(data))
# Out:
# [['Annotator', 'DataSet', 'ID', 'Text', 'Offensive', 'Slur', 'Nominalization', 'Distancing', 'Notes'], ['A', 'D', '5', 'You’re black? You don’t sound like you’re black', 'Y', 'N', 'Y', 'N', '']]
# 6791

# %%
class Tweet: 
    def __init__(self, lines):     
        self.lines = lines
        self.id = ''
        self.dataset = ''
        self.annos = []
        self.text = ''
        self.off = []
        self.slur = []
        self.adjNom = []
        self.dist = []
        self.offMaj = ''
        self.slurMaj = ''
        self.adjNomMaj = ''
        self.distMaj = ''
        self.cat = ''
        self.process()

    def process(self):
        #print(self.lines)
        for line in self.lines:
            if self.id != '':
                if line[2] != self.id:
                    print("Problem: ids don't match:", line[2], self.id)
                else: pass
            else: 
                self.id = line[2]
            if self.dataset != '':
                if line[1] != self.dataset:
                    print("Problem: datasets don't match:", line[1], self.dataset)
                else: pass
            else: 
                self.dataset = line[1]
            #if self.text != '':  ### removed this check because it catches only
                                  ### trivial differences in the texts (punctuation, etc.)
            #    if line[3] != self.text:
            #        print("Problem: texts don't match:", line[3], self.text)
            #    else: pass
            #else: 
            self.text = line[3]
            self.annos.append(line[0])
            self.off.append(line[4])
            self.slur.append(line[5])
            self.adjNom.append(line[6])
            self.dist.append(line[7])

        self.annoSet = set(self.annos)
        if len(self.annoSet) != len(self.annos):
            print("Duplicate annotations:", self.id)
            input("got it? ")
        else:
            print("No duplicates:", self.id)




    def getMajVotes(self):
        try:
            self.offMaj = statistics.mode(self.off)
        except:
            #self.offMaj = random.choice(self.off)
            print("no majority", self.id)
            self.offMaj = max(self.off) # if there's no majority, choose 'Y'
            #countTies += 1

        try:
            self.slurMaj = statistics.mode(self.slur)
        except:
            #self.slurMaj = random.choice(self.slur)
            print("no majority", self.id)
            self.slurMaj = max(self.slur)
            #countTies += 1

        try:
            self.adjNomMaj = statistics.mode(self.adjNom)
        except:
            #self.adjNomMaj = random.choice(self.adjNom)
            print("no majority", self.id)
            self.adjNomMaj = max(self.adjNom)
            #countTies += 1

        try:
            self.distMaj = statistics.mode(self.dist)
        except:
            #self.distMaj = random.choice(self.dist)
            print("no majority", self.id)
            self.distMaj = max(self.dist)
            #countTies += 1
    
    def sort(self):
        if self.offMaj == 'Y':
            if self.slurMaj == 'Y':
                #cats['offSlur'].append(self.id)
                self.cat = 'offSlur'
                return
            elif self.adjNomMaj == 'Y':
                if self.distMaj == 'Y':
                    #cats['offBoth'].append(self.id)
                    self.cat = 'offBoth'
                    return
                else:
                    #cats['offNom'].append(self.id)
                    self.cat = 'offNom'
                    return
            elif self.distMaj == 'Y':
                #cats['offDist'].append(self.id)
                self.cat = 'offDist'
                return
            else:
                #cats['offOther'].append(self.id)
                self.cat = 'offOther'
                return
        else:
            if self.slurMaj == 'Y':
                #cats['reclaimed'].append(self.id)
                self.cat = 'reclaimed'
                return
            elif self.adjNomMaj == 'Y':
                if self.distMaj == 'Y':
                    #cats['nonBoth'].append(self.id)
                    self.cat = 'nonBoth'
                    return
                else:
                    #cats['nonNom'].append(self.id)
                    self.cat = 'nonNom'
                    return
            elif self.distMaj == 'Y':
                #cats['nonDist'].append(self.id)
                self.cat = 'nonDist'
                return
            else:
                #cats['nonNone'].append(self.id)
                self.cat = 'nonNone'
                return

# %%
def fixID(line):
    #print(line)
    currID = line[2]
    currDataSet = line[1]
    if currID.startswith('D') or currID.startswith('M') or currID.startswith('C') or currID.startswith('WH'):
        pass
        #print("surprise!", currID)
        #input("okay? ")
    elif currDataSet:
        newID = currDataSet+'-'+currID
        line[2] = newID
    else:
        print("error:", currDataSet, currID)
        print(line)
        input("? ")
    return line

# %%
def selectThree(group):
    newGroup = []
    groupCopy = group
    print("starting selection on", group[0][2])
    #for line in group:
     #   anno = line[0]
      #  if anno == 'A' or anno == 'E' or anno == 'F':
            #print("selected:", anno)
      #      newGroup.append(line)
       #     groupCopy.remove(line)

        #else: pass
    while len(newGroup) < 3:
        selected = random.choice(groupCopy)
        #print("selected (rand):", selected[0])
        newGroup.append(selected)
        groupCopy.remove(selected)
    #input("selection finished - look okay? ")
    if len(newGroup) == 3:
        return newGroup
    else:
        print("problem:", len(newGroup))

# %%
cats = {'offSlur': [], 'offNom': [], 'offDist': [], 'offBoth': [], 'offOther': [], 'reclaimed': [], 'nonNom': [], 'nonDist': [], 'nonBoth': [], 'nonNone': []}
ties = []

check_annos = {1:[], 2:[], 3:[], 4:[], 5:[], 6:[], 7:[]}
tweets3 = []
tweets2or1 = []
tweets4orMore = []
prevID = ''
thisID = ''
group = []
print(len(data))
for line in data[1:]:
    if len(line) != 9:
        print(line)
        input("okay? ")
    line = fixID(line)
    #print(line)
    #print(prevID, thisID)
    #print(len(group))
    #input("okay? ")
    thisID = line[2]
    if thisID == prevID:
        group.append(line)
    elif prevID == '':
        group.append(line)
    elif thisID == 'ID':
        pass
    else:
        num = len(group)
        if num == 3:       ### process tweets with 3 annos
            check_annos[3].append(prevID)
            tweets3.append(Tweet(group))
        elif num == 2 or num == 1:  ### process tweets with 1 or 2 annos (will be removed)
            check_annos[num].append(prevID)
            tweets2or1.append(Tweet(group))
        else:         #### process tweets with more than 3 annos (3 annos will be selected, added to set of tweets with 3 annos)
            newGroup = selectThree(group)
            check_annos[num].append(prevID)
            tweets3.append(Tweet(newGroup))
            tweets4orMore.append(Tweet(group))
            newGroup = []
        group = [line]
    prevID = thisID
# Out:
# 6791
# No duplicates: D-5
# No duplicates: D-6
# starting selection on M-6
# No duplicates: M-6
# No duplicates: M-6
# No duplicates: C-11
# No duplicates: D-13
# No duplicates: D-15
# No duplicates: M-22
# No duplicates: M-23
# No duplicates: M-24
# No duplicates: M-27
# No duplicates: M-28
# No duplicates: M-29
# No duplicates: M-30
# No duplicates: M-32
# No duplicates: M-34
# No duplicates: M-36
# No duplicates: M-37
# No duplicates: M-38
# No duplicates: M-45
# No duplicates: M-46
# No duplicates: M-47
# No duplicates: M-48
# No duplicates: M-49
# No duplicates: M-53
# No duplicates: M-54
# No duplicates: M-55
# No duplicates: M-56
# No duplicates: M-57
# No duplicates: M-59
# No duplicates: M-61
# No duplicates: D-63
# No duplicates: M-63
# No duplicates: M-64
# No duplicates: M-66
# No duplicates: M-67
# No duplicates: M-68
# No duplicates: D-70
# No duplicates: M-71
# No duplicates: M-73
# No duplicates: M-74
# starting selection on M-79
# No duplicates: M-79
# No duplicates: M-79
# No duplicates: M-83
# starting selection on M-84
# No duplicates: M-84
# No duplicates: M-84
# No duplicates: M-87
# No duplicates: D-90
# starting selection on M-91
# No duplicates: M-91
# No duplicates: M-91
# starting selection on M-92
# No duplicates: M-92
# No duplicates: M-92
# No duplicates: D-95
# starting selection on M-97
# No duplicates: M-97
# No duplicates: M-97
# No duplicates: M-100
# No duplicates: M-102
# No duplicates: M-104
# No duplicates: M-106
# No duplicates: M-108
# No duplicates: M-110
# No duplicates: M-112
# No duplicates: M-113
# No duplicates: M-114
# No duplicates: D-116
# No duplicates: D-119
# No duplicates: D-121
# No duplicates: D-123
# No duplicates: M-123
# No duplicates: M-124
# No duplicates: D-125
# No duplicates: M-126
# No duplicates: M-129
# No duplicates: M-130
# No duplicates: M-133
# No duplicates: M-134
# No duplicates: M-135
# No duplicates: M-136
# No duplicates: M-137
# No duplicates: M-138
# No duplicates: M-140
# No duplicates: M-141
# No duplicates: M-142
# No duplicates: M-145
# No duplicates: M-148
# No duplicates: M-150
# No duplicates: M-151
# No duplicates: M-153
# No duplicates: M-155
# No duplicates: M-157
# No duplicates: M-160
# No duplicates: M-161
# No duplicates: D-166
# No duplicates: M-166
# No duplicates: M-168
# No duplicates: M-170
# No duplicates: M-171
# No duplicates: M-175
# No duplicates: M-178
# No duplicates: D-182
# No duplicates: M-182
# No duplicates: D-183
# No duplicates: M-184
# starting selection on D-186
# No duplicates: D-186
# No duplicates: D-186
# No duplicates: M-187
# No duplicates: M-189
# No duplicates: D-192
# No duplicates: M-195
# No duplicates: D-198
# No duplicates: M-200
# No duplicates: D-204
# No duplicates: D-206
# No duplicates: M-207
# No duplicates: D-209
# No duplicates: M-209
# No duplicates: M-212
# starting selection on M-213
# No duplicates: M-213
# No duplicates: M-213
# starting selection on D-218
# No duplicates: D-218
# No duplicates: D-218
# starting selection on D-221
# No duplicates: D-221
# No duplicates: D-221
# No duplicates: M-241
# No duplicates: M-243
# No duplicates: M-244
# No duplicates: M-249
# No duplicates: M-252
# No duplicates: M-257
# starting selection on M-259
# No duplicates: M-259
# No duplicates: M-259
# No duplicates: M-260
# No duplicates: M-262
# No duplicates: D-263
# No duplicates: M-264
# No duplicates: M-271
# No duplicates: D-272
# No duplicates: M-275
# No duplicates: D-277
# starting selection on M-277
# No duplicates: M-277
# No duplicates: M-277
# No duplicates: M-279
# No duplicates: M-281
# No duplicates: D-287
# No duplicates: M-289
# No duplicates: M-292
# starting selection on M-301
# No duplicates: M-301
# No duplicates: M-301
# starting selection on M-302
# No duplicates: M-302
# No duplicates: M-302
# starting selection on M-303
# No duplicates: M-303
# No duplicates: M-303
# starting selection on M-311
# No duplicates: M-311
# No duplicates: M-311
# starting selection on M-313
# No duplicates: M-313
# No duplicates: M-313
# starting selection on M-314
# No duplicates: M-314
# No duplicates: M-314
# No duplicates: D-318
# No duplicates: D-319
# starting selection on D-320
# No duplicates: D-320
# No duplicates: D-320
# No duplicates: M-325
# No duplicates: M-326
# No duplicates: M-327
# No duplicates: M-328
# No duplicates: D-329
# No duplicates: D-334
# starting selection on M-335
# No duplicates: M-335
# No duplicates: M-335
# No duplicates: D-336
# No duplicates: M-339
# No duplicates: D-341
# No duplicates: M-342
# No duplicates: D-346
# No duplicates: M-346
# No duplicates: M-352
# No duplicates: D-354
# No duplicates: D-356
# No duplicates: M-357
# No duplicates: D-361
# No duplicates: D-369
# No duplicates: D-373
# No duplicates: D-375
# starting selection on M-377
# No duplicates: M-377
# No duplicates: M-377
# No duplicates: M-378
# No duplicates: M-380
# No duplicates: M-381
# No duplicates: M-382
# No duplicates: M-383
# No duplicates: M-384
# No duplicates: M-385
# No duplicates: M-386
# No duplicates: M-387
# No duplicates: M-389
# No duplicates: M-391
# No duplicates: M-393
# No duplicates: M-394
# No duplicates: M-395
# No duplicates: M-396
# No duplicates: M-397
# No duplicates: D-398
# No duplicates: M-398
# No duplicates: M-399
# No duplicates: M-400
# starting selection on M-401
# No duplicates: M-401
# No duplicates: M-401
# No duplicates: M-402
# No duplicates: M-403
# starting selection on M-404
# No duplicates: M-404
# No duplicates: M-404
# No duplicates: M-405
# starting selection on M-406
# No duplicates: M-406
# No duplicates: M-406
# No duplicates: M-423
# No duplicates: D-424
# No duplicates: M-424
# No duplicates: D-434
# No duplicates: D-442
# No duplicates: D-443
# No duplicates: D-453
# No duplicates: D-455
# No duplicates: M-458
# No duplicates: M-463
# No duplicates: D-464
# starting selection on D-466
# No duplicates: D-466
# No duplicates: D-466
# starting selection on D-468
# No duplicates: D-468
# No duplicates: D-468
# No duplicates: M-473
# No duplicates: D-474
# No duplicates: M-487
# No duplicates: M-489
# No duplicates: M-495
# No duplicates: M-503
# No duplicates: D-522
# No duplicates: D-524
# No duplicates: D-528
# No duplicates: M-530
# No duplicates: M-540
# No duplicates: D-546
# starting selection on D-549
# No duplicates: D-549
# No duplicates: D-549
# No duplicates: M-566
# No duplicates: D-570
# No duplicates: D-571
# No duplicates: D-574
# No duplicates: D-577
# No duplicates: D-580
# No duplicates: D-584
# No duplicates: D-585
# starting selection on D-591
# No duplicates: D-591
# No duplicates: D-591
# No duplicates: D-594
# No duplicates: D-597
# starting selection on D-598
# No duplicates: D-598
# No duplicates: D-598
# No duplicates: M-603
# starting selection on D-607
# No duplicates: D-607
# No duplicates: D-607
# No duplicates: D-608
# No duplicates: M-613
# No duplicates: M-614
# No duplicates: M-615
# No duplicates: M-616
# No duplicates: D-617
# No duplicates: D-618
# No duplicates: D-619
# No duplicates: M-621
# No duplicates: M-622
# No duplicates: D-624
# No duplicates: M-624
# No duplicates: D-626
# No duplicates: M-626
# No duplicates: M-627
# No duplicates: D-631
# No duplicates: M-632
# No duplicates: M-633
# No duplicates: M-636
# No duplicates: M-638
# No duplicates: M-639
# No duplicates: M-640
# No duplicates: M-641
# No duplicates: M-644
# No duplicates: D-645
# No duplicates: M-645
# No duplicates: M-646
# No duplicates: M-649
# No duplicates: M-650
# No duplicates: M-655
# No duplicates: D-656
# No duplicates: D-657
# No duplicates: M-658
# No duplicates: M-660
# No duplicates: M-661
# No duplicates: M-663
# No duplicates: M-668
# No duplicates: M-669
# starting selection on D-670
# No duplicates: D-670
# No duplicates: D-670
# No duplicates: M-670
# No duplicates: D-673
# No duplicates: M-673
# No duplicates: M-674
# No duplicates: M-675
# No duplicates: M-676
# No duplicates: M-677
# No duplicates: D-678
# No duplicates: M-678
# No duplicates: D-682
# No duplicates: D-684
# starting selection on D-686
# No duplicates: D-686
# No duplicates: D-686
# No duplicates: D-687
# No duplicates: D-688
# starting selection on D-689
# No duplicates: D-689
# No duplicates: D-689
# No duplicates: D-690
# No duplicates: D-691
# No duplicates: D-693
# No duplicates: D-694
# starting selection on D-700
# No duplicates: D-700
# No duplicates: D-700
# No duplicates: D-704
# No duplicates: D-708
# starting selection on D-710
# No duplicates: D-710
# No duplicates: D-710
# No duplicates: D-711
# No duplicates: D-725
# No duplicates: D-729
# No duplicates: D-735
# starting selection on D-736
# No duplicates: D-736
# No duplicates: D-736
# No duplicates: D-740
# No duplicates: D-742
# No duplicates: D-743
# starting selection on D-744
# No duplicates: D-744
# No duplicates: D-744
# No duplicates: D-745
# No duplicates: D-746
# No duplicates: D-750
# No duplicates: D-753
# No duplicates: D-754
# No duplicates: D-755
# No duplicates: D-757
# No duplicates: D-758
# No duplicates: D-759
# No duplicates: M-760
# No duplicates: D-762
# No duplicates: D-763
# No duplicates: D-768
# No duplicates: D-772
# No duplicates: D-775
# No duplicates: D-776
# No duplicates: D-778
# No duplicates: D-779
# No duplicates: D-780
# No duplicates: D-782
# No duplicates: D-783
# No duplicates: D-784
# No duplicates: D-788
# No duplicates: D-790
# No duplicates: D-791
# No duplicates: D-795
# No duplicates: D-796
# No duplicates: D-797
# No duplicates: D-803
# No duplicates: D-807
# No duplicates: D-808
# No duplicates: D-811
# No duplicates: D-812
# No duplicates: D-815
# No duplicates: D-816
# No duplicates: D-820
# No duplicates: D-821
# No duplicates: D-822
# No duplicates: D-823
# No duplicates: D-824
# No duplicates: D-826
# No duplicates: D-829
# No duplicates: D-831
# starting selection on D-832
# No duplicates: D-832
# No duplicates: D-832
# No duplicates: D-833
# No duplicates: D-834
# No duplicates: D-835
# No duplicates: D-836
# No duplicates: D-837
# No duplicates: D-841
# No duplicates: D-843
# No duplicates: D-848
# No duplicates: D-850
# No duplicates: D-851
# No duplicates: D-853
# No duplicates: D-856
# No duplicates: D-859
# No duplicates: D-860
# No duplicates: D-864
# No duplicates: D-867
# No duplicates: D-868
# No duplicates: D-869
# No duplicates: D-872
# No duplicates: D-875
# No duplicates: D-925
# No duplicates: D-929
# No duplicates: D-931
# No duplicates: D-933
# No duplicates: D-935
# No duplicates: D-938
# No duplicates: D-945
# No duplicates: D-953
# No duplicates: D-956
# No duplicates: D-958
# No duplicates: D-980
# No duplicates: D-988
# No duplicates: M-995
# No duplicates: M-997
# No duplicates: D-998
# No duplicates: M-998
# No duplicates: D-999
# No duplicates: D-1000
# starting selection on M-1000
# No duplicates: M-1000
# No duplicates: M-1000
# starting selection on M-1001
# No duplicates: M-1001
# No duplicates: M-1001
# starting selection on M-1002
# No duplicates: M-1002
# No duplicates: M-1002
# starting selection on M-1003
# No duplicates: M-1003
# No duplicates: M-1003
# starting selection on M-1004
# No duplicates: M-1004
# Duplicate annotations: M-1004
# got it?
# starting selection on M-1005
# No duplicates: M-1005
# No duplicates: M-1005
# No duplicates: M-1006
# No duplicates: M-1007
# No duplicates: M-1008
# No duplicates: M-1009
# No duplicates: M-1010
# No duplicates: M-1011
# No duplicates: M-1012
# No duplicates: M-1014
# No duplicates: M-1015
# No duplicates: M-1016
# No duplicates: M-1017
# No duplicates: M-1019
# No duplicates: M-1020
# No duplicates: M-1021
# No duplicates: M-1023
# No duplicates: D-1027
# No duplicates: D-1029
# No duplicates: D-1036
# No duplicates: D-1040
# No duplicates: D-1044
# No duplicates: D-1045
# No duplicates: D-1052
# No duplicates: D-1054
# No duplicates: D-1071
# No duplicates: D-1074
# No duplicates: D-1090
# No duplicates: D-1091
# No duplicates: D-1092
# No duplicates: M-1103
# No duplicates: M-1104
# No duplicates: M-1110
# No duplicates: D-1111
# No duplicates: D-1112
# No duplicates: D-1115
# No duplicates: D-1117
# No duplicates: D-1121
# No duplicates: D-1126
# No duplicates: D-1132
# starting selection on D-1138
# No duplicates: D-1138
# No duplicates: D-1138
# No duplicates: D-1141
# No duplicates: D-1142
# No duplicates: D-1143
# No duplicates: D-1159
# No duplicates: D-1160
# No duplicates: D-1167
# No duplicates: D-1170
# No duplicates: D-1173
# No duplicates: D-1194
# No duplicates: D-1205
# No duplicates: D-1220
# No duplicates: D-1227
# No duplicates: D-1233
# No duplicates: D-1248
# No duplicates: D-1249
# No duplicates: D-1250
# No duplicates: D-1251
# No duplicates: D-1252
# No duplicates: D-1253
# No duplicates: D-1255
# No duplicates: D-1256
# No duplicates: D-1257
# No duplicates: D-1258
# starting selection on D-1259
# No duplicates: D-1259
# No duplicates: D-1259
# No duplicates: D-1260
# No duplicates: D-1261
# No duplicates: D-1262
# No duplicates: D-1263
# No duplicates: D-1265
# No duplicates: D-1266
# No duplicates: D-1268
# No duplicates: D-1269
# No duplicates: D-1273
# No duplicates: D-1274
# No duplicates: D-1275
# No duplicates: D-1276
# No duplicates: D-1277
# No duplicates: D-1278
# No duplicates: D-1281
# starting selection on D-1288
# No duplicates: D-1288
# No duplicates: D-1288
# No duplicates: D-1305
# No duplicates: D-1308
# No duplicates: D-1315
# No duplicates: D-1325
# No duplicates: D-1326
# No duplicates: D-1333
# No duplicates: D-1337
# No duplicates: D-1340
# No duplicates: D-1348
# No duplicates: D-1349
# No duplicates: D-1371
# No duplicates: D-1372
# No duplicates: D-1390
# No duplicates: D-1398
# No duplicates: D-1412
# No duplicates: D-1423
# No duplicates: D-1434
# No duplicates: D-1442
# No duplicates: D-1448
# No duplicates: D-1450
# No duplicates: D-1452
# No duplicates: D-1461
# No duplicates: D-1466
# No duplicates: D-1467
# No duplicates: D-1468
# No duplicates: D-1474
# No duplicates: D-1485
# starting selection on D-1495
# No duplicates: D-1495
# No duplicates: D-1495
# No duplicates: D-1497
# No duplicates: D-1498
# No duplicates: D-1499
# No duplicates: D-1500
# No duplicates: D-1505
# No duplicates: D-1506
# No duplicates: D-1508
# No duplicates: D-1527
# No duplicates: D-1543
# No duplicates: D-1546
# No duplicates: D-1552
# No duplicates: D-1554
# No duplicates: D-1560
# starting selection on D-1576
# No duplicates: D-1576
# No duplicates: D-1576
# No duplicates: D-1578
# No duplicates: D-1600
# No duplicates: D-1601
# No duplicates: D-1617
# No duplicates: D-1626
# starting selection on D-1636
# No duplicates: D-1636
# No duplicates: D-1636
# starting selection on D-1643
# No duplicates: D-1643
# No duplicates: D-1643
# No duplicates: D-1650
# No duplicates: D-1651
# No duplicates: D-1652
# No duplicates: D-1655
# No duplicates: D-1668
# No duplicates: D-1701
# No duplicates: D-1702
# No duplicates: D-1715
# No duplicates: D-1728
# No duplicates: D-1729
# No duplicates: D-1730
# starting selection on D-1731
# No duplicates: D-1731
# No duplicates: D-1731
# No duplicates: D-1736
# No duplicates: D-1743
# No duplicates: D-1745
# No duplicates: D-1763
# No duplicates: D-1765
# No duplicates: D-1766
# No duplicates: D-1770
# No duplicates: D-1782
# No duplicates: D-1787
# No duplicates: D-1805
# No duplicates: D-1812
# No duplicates: D-1813
# No duplicates: D-1821
# No duplicates: D-1825
# starting selection on D-1826
# No duplicates: D-1826
# No duplicates: D-1826
# No duplicates: D-1842
# No duplicates: D-1872
# No duplicates: D-1877
# No duplicates: D-1879
# No duplicates: D-1891
# No duplicates: D-1906
# No duplicates: D-1907
# No duplicates: D-1913
# No duplicates: D-1923
# No duplicates: D-1948
# No duplicates: D-1949
# No duplicates: D-1963
# No duplicates: D-1964
# No duplicates: D-1972
# No duplicates: D-1977
# starting selection on D-1986
# No duplicates: D-1986
# No duplicates: D-1986
# No duplicates: D-1987
# No duplicates: D-1989
# starting selection on D-1991
# No duplicates: D-1991
# No duplicates: D-1991
# No duplicates: D-2033
# No duplicates: D-2036
# No duplicates: D-2046
# starting selection on D-2050
# No duplicates: D-2050
# No duplicates: D-2050
# starting selection on D-2051
# No duplicates: D-2051
# No duplicates: D-2051
# No duplicates: D-2057
# No duplicates: D-2065
# No duplicates: D-2068
# No duplicates: D-2071
# No duplicates: D-2077
# No duplicates: D-2078
# No duplicates: D-2088
# No duplicates: D-2098
# No duplicates: D-2106
# No duplicates: D-2113
# No duplicates: D-2121
# starting selection on D-2129
# No duplicates: D-2129
# No duplicates: D-2129
# No duplicates: D-2131
# No duplicates: D-2137
# No duplicates: D-2146
# No duplicates: D-2149
# No duplicates: D-2152
# No duplicates: D-2155
# No duplicates: D-2157
# No duplicates: D-2159
# starting selection on D-2170
# No duplicates: D-2170
# No duplicates: D-2170
# No duplicates: D-2172
# No duplicates: D-2175
# starting selection on D-2176
# No duplicates: D-2176
# No duplicates: D-2176
# No duplicates: D-2177
# starting selection on D-2179
# No duplicates: D-2179
# No duplicates: D-2179
# starting selection on D-2180
# No duplicates: D-2180
# No duplicates: D-2180
# starting selection on D-2182
# No duplicates: D-2182
# No duplicates: D-2182
# starting selection on D-2188
# No duplicates: D-2188
# No duplicates: D-2188
# No duplicates: D-2194
# starting selection on D-2202
# No duplicates: D-2202
# No duplicates: D-2202
# No duplicates: D-2204
# starting selection on D-2205
# No duplicates: D-2205
# No duplicates: D-2205
# No duplicates: D-2219
# starting selection on D-2223
# No duplicates: D-2223
# No duplicates: D-2223
# starting selection on D-2224
# No duplicates: D-2224
# No duplicates: D-2224
# No duplicates: D-2225
# No duplicates: D-2227
# starting selection on D-2229
# No duplicates: D-2229
# No duplicates: D-2229
# No duplicates: D-2231
# No duplicates: D-2233
# No duplicates: D-2234
# No duplicates: D-2236
# starting selection on D-2247
# No duplicates: D-2247
# No duplicates: D-2247
# No duplicates: D-2259
# No duplicates: D-2267
# No duplicates: D-2268
# No duplicates: D-2271
# No duplicates: D-2272
# No duplicates: D-2273
# No duplicates: D-2274
# No duplicates: D-2276
# No duplicates: D-2284
# No duplicates: D-2299
# No duplicates: D-2301
# No duplicates: D-2306
# starting selection on D-2307
# No duplicates: D-2307
# No duplicates: D-2307
# starting selection on D-2308
# No duplicates: D-2308
# No duplicates: D-2308
# No duplicates: D-2309
# No duplicates: D-2310
# No duplicates: D-2320
# No duplicates: D-2321
# No duplicates: D-2322
# No duplicates: D-2325
# No duplicates: D-2342
# No duplicates: D-2346
# No duplicates: D-2351
# No duplicates: D-2353
# No duplicates: D-2354
# starting selection on D-2360
# No duplicates: D-2360
# No duplicates: D-2360
# No duplicates: D-2361
# No duplicates: D-2362
# No duplicates: D-2370
# starting selection on D-2374
# No duplicates: D-2374
# No duplicates: D-2374
# No duplicates: D-2380
# No duplicates: D-2381
# No duplicates: D-2393
# No duplicates: D-2394
# No duplicates: D-2396
# No duplicates: D-2398
# No duplicates: D-2411
# No duplicates: D-2421
# No duplicates: D-2423
# starting selection on D-2426
# No duplicates: D-2426
# No duplicates: D-2426
# No duplicates: D-2434
# No duplicates: D-2448
# No duplicates: D-2450
# starting selection on D-2457
# No duplicates: D-2457
# No duplicates: D-2457
# No duplicates: D-2458
# starting selection on D-2465
# No duplicates: D-2465
# No duplicates: D-2465
# No duplicates: D-2466
# No duplicates: D-2477
# No duplicates: D-2482
# No duplicates: D-2488
# No duplicates: D-2489
# No duplicates: D-2491
# No duplicates: D-2495
# No duplicates: D-2497
# No duplicates: D-2499
# No duplicates: D-2505
# No duplicates: D-2507
# No duplicates: D-2508
# No duplicates: D-2510
# No duplicates: D-2516
# No duplicates: D-2517
# No duplicates: D-2523
# No duplicates: D-2524
# No duplicates: D-2543
# No duplicates: D-2546
# No duplicates: D-2549
# starting selection on D-2550
# No duplicates: D-2550
# No duplicates: D-2550
# No duplicates: D-2552
# No duplicates: D-2553
# No duplicates: D-2556
# No duplicates: D-2558
# No duplicates: D-2561
# No duplicates: D-2575
# No duplicates: D-2583
# No duplicates: D-2601
# starting selection on D-2604
# No duplicates: D-2604
# No duplicates: D-2604
# No duplicates: D-2606
# No duplicates: D-2612
# No duplicates: D-2618
# No duplicates: D-2621
# No duplicates: D-2627
# No duplicates: D-2629
# No duplicates: D-2642
# No duplicates: D-2644
# No duplicates: D-2645
# No duplicates: D-2653
# No duplicates: D-2656
# No duplicates: D-2658
# No duplicates: D-2661
# No duplicates: D-2667
# No duplicates: D-2678
# No duplicates: D-2680
# No duplicates: D-2687
# No duplicates: D-2688
# No duplicates: D-2690
# No duplicates: D-2693
# No duplicates: D-2697
# No duplicates: D-2698
# No duplicates: D-2709
# No duplicates: D-2711
# No duplicates: D-2712
# No duplicates: D-2713
# No duplicates: D-2715
# No duplicates: D-2719
# starting selection on D-2724
# No duplicates: D-2724
# No duplicates: D-2724
# No duplicates: D-2731
# No duplicates: D-2733
# No duplicates: D-2736
# No duplicates: D-2737
# No duplicates: D-2742
# No duplicates: D-2743
# No duplicates: D-2747
# No duplicates: D-2749
# No duplicates: D-2750
# No duplicates: D-2751
# No duplicates: D-2762
# No duplicates: D-2763
# No duplicates: D-2766
# No duplicates: D-2767
# No duplicates: D-2770
# No duplicates: D-2772
# No duplicates: D-2775
# No duplicates: D-2776
# No duplicates: D-2778
# No duplicates: D-2780
# No duplicates: D-2783
# No duplicates: D-2787
# starting selection on D-2790
# No duplicates: D-2790
# No duplicates: D-2790
# No duplicates: D-2821
# No duplicates: D-2822
# No duplicates: D-2827
# No duplicates: D-2829
# starting selection on D-2843
# No duplicates: D-2843
# No duplicates: D-2843
# No duplicates: D-2844
# No duplicates: WH-2847
# starting selection on D-2848
# No duplicates: D-2848
# No duplicates: D-2848
# No duplicates: D-2853
# No duplicates: D-2858
# No duplicates: D-2867
# No duplicates: D-2877
# No duplicates: D-2885
# No duplicates: D-2886
# No duplicates: D-2888
# No duplicates: D-2891
# No duplicates: D-2892
# No duplicates: D-2894
# No duplicates: D-2896
# No duplicates: D-2899
# starting selection on D-2901
# No duplicates: D-2901
# No duplicates: D-2901
# No duplicates: D-2902
# No duplicates: D-2908
# No duplicates: D-2912
# No duplicates: D-2920
# No duplicates: D-2922
# No duplicates: D-2923
# No duplicates: D-2932
# No duplicates: D-2935
# No duplicates: D-2936
# No duplicates: D-2938
# starting selection on D-2939
# No duplicates: D-2939
# No duplicates: D-2939
# starting selection on D-2940
# No duplicates: D-2940
# No duplicates: D-2940
# No duplicates: D-2958
# No duplicates: D-2960
# No duplicates: D-2972
# No duplicates: D-2973
# No duplicates: D-2983
# No duplicates: D-2997
# No duplicates: D-3011
# No duplicates: D-3018
# No duplicates: D-3034
# No duplicates: D-3040
# No duplicates: D-3041
# No duplicates: D-3043
# No duplicates: D-3048
# No duplicates: D-3051
# No duplicates: D-3057
# No duplicates: D-3062
# No duplicates: D-3064
# No duplicates: D-3077
# No duplicates: D-3078
# No duplicates: D-3081
# No duplicates: D-3082
# No duplicates: D-3087
# No duplicates: D-3088
# No duplicates: D-3090
# No duplicates: D-3094
# No duplicates: D-3100
# No duplicates: D-3118
# No duplicates: D-3121
# No duplicates: D-3125
# No duplicates: D-3126
# No duplicates: D-3131
# No duplicates: D-3151
# No duplicates: D-3152
# starting selection on D-3167
# No duplicates: D-3167
# No duplicates: D-3167
# No duplicates: D-3168
# No duplicates: D-3177
# No duplicates: D-3191
# No duplicates: D-3197
# No duplicates: D-3200
# starting selection on D-3204
# No duplicates: D-3204
# No duplicates: D-3204
# starting selection on D-3205
# No duplicates: D-3205
# No duplicates: D-3205
# No duplicates: D-3206
# starting selection on D-3214
# No duplicates: D-3214
# No duplicates: D-3214
# No duplicates: D-3216
# No duplicates: D-3220
# No duplicates: D-3225
# No duplicates: D-3226
# No duplicates: D-3232
# No duplicates: D-3234
# No duplicates: D-3239
# No duplicates: D-3255
# No duplicates: D-3265
# No duplicates: D-3266
# No duplicates: D-3268
# No duplicates: D-3270
# No duplicates: D-3272
# No duplicates: D-3273
# No duplicates: D-3274
# No duplicates: D-3280
# No duplicates: D-3281
# No duplicates: D-3283
# No duplicates: D-3286
# No duplicates: D-3287
# No duplicates: D-3294
# starting selection on D-3313
# No duplicates: D-3313
# No duplicates: D-3313
# No duplicates: D-3314
# No duplicates: D-3315
# starting selection on D-3319
# No duplicates: D-3319
# No duplicates: D-3319
# No duplicates: D-3324
# No duplicates: D-3325
# No duplicates: D-3326
# No duplicates: D-3343
# No duplicates: D-3346
# No duplicates: D-3356
# No duplicates: D-3357
# No duplicates: D-3361
# No duplicates: D-3364
# No duplicates: D-3366
# No duplicates: D-3371
# starting selection on D-3378
# No duplicates: D-3378
# No duplicates: D-3378
# No duplicates: D-3379
# No duplicates: D-3389
# No duplicates: D-3396
# No duplicates: D-3401
# No duplicates: D-3402
# No duplicates: D-3404
# No duplicates: D-3407
# No duplicates: D-3411
# No duplicates: D-3412
# No duplicates: D-3416
# No duplicates: D-3434
# No duplicates: D-3436
# No duplicates: D-3442
# starting selection on D-3454
# No duplicates: D-3454
# No duplicates: D-3454
# No duplicates: D-3456
# No duplicates: D-3468
# No duplicates: D-3477
# No duplicates: D-3488
# No duplicates: D-3489
# No duplicates: D-3492
# No duplicates: D-3493
# No duplicates: D-3496
# No duplicates: D-3498
# No duplicates: D-3510
# No duplicates: D-3517
# No duplicates: D-3523
# starting selection on D-3532
# No duplicates: D-3532
# No duplicates: D-3532
# No duplicates: D-3538
# No duplicates: D-3550
# No duplicates: D-3559
# No duplicates: D-3561
# starting selection on D-3574
# No duplicates: D-3574
# No duplicates: D-3574
# starting selection on D-3582
# No duplicates: D-3582
# No duplicates: D-3582
# No duplicates: D-3589
# No duplicates: D-3604
# starting selection on D-3610
# No duplicates: D-3610
# No duplicates: D-3610
# starting selection on D-3612
# No duplicates: D-3612
# No duplicates: D-3612
# No duplicates: D-3613
# No duplicates: D-3620
# No duplicates: D-3648
# No duplicates: D-3655
# starting selection on D-3667
# No duplicates: D-3667
# No duplicates: D-3667
# No duplicates: D-3669
# starting selection on D-3682
# No duplicates: D-3682
# No duplicates: D-3682
# No duplicates: D-3686
# No duplicates: D-3689
# No duplicates: D-3692
# No duplicates: D-3703
# starting selection on D-3729
# No duplicates: D-3729
# No duplicates: D-3729
# No duplicates: D-3739
# starting selection on D-3747
# No duplicates: D-3747
# No duplicates: D-3747
# No duplicates: D-3749
# No duplicates: D-3777
# No duplicates: D-3783
# starting selection on D-3791
# No duplicates: D-3791
# No duplicates: D-3791
# starting selection on D-3796
# No duplicates: D-3796
# No duplicates: D-3796
# No duplicates: D-3801
# starting selection on D-3802
# No duplicates: D-3802
# No duplicates: D-3802
# No duplicates: D-3803
# starting selection on D-3808
# No duplicates: D-3808
# No duplicates: D-3808
# starting selection on D-3823
# No duplicates: D-3823
# No duplicates: D-3823
# starting selection on D-3824
# No duplicates: D-3824
# No duplicates: D-3824
# starting selection on D-3843
# No duplicates: D-3843
# No duplicates: D-3843
# starting selection on D-3851
# No duplicates: D-3851
# No duplicates: D-3851
# No duplicates: D-3859
# No duplicates: D-3870
# No duplicates: D-3879
# No duplicates: D-3880
# No duplicates: D-3884
# starting selection on D-3889
# No duplicates: D-3889
# No duplicates: D-3889
# No duplicates: D-3892
# starting selection on D-3894
# No duplicates: D-3894
# No duplicates: D-3894
# starting selection on D-3899
# No duplicates: D-3899
# No duplicates: D-3899
# No duplicates: D-3900
# No duplicates: D-3901
# No duplicates: D-3903
# No duplicates: D-3906
# No duplicates: D-3907
# No duplicates: D-3909
# starting selection on D-3922
# No duplicates: D-3922
# No duplicates: D-3922
# No duplicates: D-3929
# starting selection on D-3937
# No duplicates: D-3937
# No duplicates: D-3937
# starting selection on D-3943
# No duplicates: D-3943
# No duplicates: D-3943
# starting selection on D-3949
# No duplicates: D-3949
# No duplicates: D-3949
# starting selection on D-3957
# No duplicates: D-3957
# No duplicates: D-3957
# starting selection on D-3963
# No duplicates: D-3963
# No duplicates: D-3963
# starting selection on D-3964
# No duplicates: D-3964
# No duplicates: D-3964
# starting selection on D-3966
# No duplicates: D-3966
# No duplicates: D-3966
# No duplicates: D-3969
# starting selection on D-3971
# No duplicates: D-3971
# No duplicates: D-3971
# No duplicates: D-3976
# No duplicates: D-3980
# starting selection on D-3982
# No duplicates: D-3982
# No duplicates: D-3982
# No duplicates: D-3985
# No duplicates: D-3999
# No duplicates: D-4002
# No duplicates: D-4016
# No duplicates: D-4023
# No duplicates: D-4025
# No duplicates: D-4026
# No duplicates: D-4030
# No duplicates: D-4033
# No duplicates: D-4034
# No duplicates: D-4069
# No duplicates: D-4071
# No duplicates: D-4077
# No duplicates: D-4083
# starting selection on D-4097
# No duplicates: D-4097
# No duplicates: D-4097
# No duplicates: D-4102
# starting selection on D-4113
# No duplicates: D-4113
# No duplicates: D-4113
# No duplicates: D-4114
# No duplicates: D-4118
# No duplicates: D-4124
# No duplicates: D-4129
# No duplicates: D-4140
# No duplicates: D-4152
# starting selection on D-4157
# No duplicates: D-4157
# No duplicates: D-4157
# No duplicates: D-4166
# No duplicates: D-4167
# No duplicates: D-4168
# No duplicates: D-4180
# No duplicates: D-4183
# No duplicates: D-4184
# No duplicates: D-4185
# No duplicates: D-4198
# No duplicates: D-4199
# No duplicates: D-4218
# No duplicates: D-4230
# No duplicates: D-4232
# No duplicates: D-4237
# No duplicates: D-4244
# No duplicates: D-4258
# No duplicates: D-4259
# No duplicates: D-4260
# No duplicates: D-4267
# No duplicates: D-4278
# starting selection on D-4285
# No duplicates: D-4285
# No duplicates: D-4285
# No duplicates: D-4288
# No duplicates: D-4289
# No duplicates: D-4294
# No duplicates: D-4296
# No duplicates: D-4309
# No duplicates: D-4315
# No duplicates: D-4318
# No duplicates: D-4328
# No duplicates: D-4339
# No duplicates: D-4346
# No duplicates: D-4347
# No duplicates: D-4350
# No duplicates: D-4373
# No duplicates: D-4459
# No duplicates: D-4460
# No duplicates: D-4466
# No duplicates: D-4511
# No duplicates: D-4519
# No duplicates: D-4572
# No duplicates: D-4573
# No duplicates: D-4576
# No duplicates: D-4603
# No duplicates: D-4610
# No duplicates: D-4626
# No duplicates: D-4629
# No duplicates: D-4645
# No duplicates: D-4650
# No duplicates: D-4660
# No duplicates: D-4681
# No duplicates: D-4719
# No duplicates: D-4743
# No duplicates: D-4765
# No duplicates: D-4772
# No duplicates: D-4773
# No duplicates: D-4775
# No duplicates: D-4794
# starting selection on D-4853
# No duplicates: D-4853
# No duplicates: D-4853
# No duplicates: D-4854
# No duplicates: D-4864
# No duplicates: D-4879
# No duplicates: D-4888
# No duplicates: D-4889
# No duplicates: D-4890
# No duplicates: D-4895
# No duplicates: D-4897
# starting selection on D-4904
# No duplicates: D-4904
# No duplicates: D-4904
# starting selection on D-4912
# No duplicates: D-4912
# No duplicates: D-4912
# No duplicates: D-4913
# No duplicates: D-4962
# No duplicates: D-4972
# No duplicates: D-4997
# No duplicates: D-5031
# No duplicates: D-5073
# No duplicates: D-5076
# No duplicates: D-5125
# No duplicates: D-5128
# starting selection on D-5151
# No duplicates: D-5151
# No duplicates: D-5151
# No duplicates: D-5167
# No duplicates: D-5180
# No duplicates: D-5191
# No duplicates: D-5253
# No duplicates: D-5254
# No duplicates: D-5255
# No duplicates: D-5268
# No duplicates: D-5275
# No duplicates: D-5278
# No duplicates: D-5295
# No duplicates: D-5318
# No duplicates: D-5429
# No duplicates: D-5433
# No duplicates: D-5449
# No duplicates: D-5466
# No duplicates: D-5480
# No duplicates: D-5498
# No duplicates: D-5542
# No duplicates: D-5555
# No duplicates: D-5558
# No duplicates: D-5586
# No duplicates: D-5696
# No duplicates: D-5699
# No duplicates: D-5708
# No duplicates: D-5709
# No duplicates: D-5713
# No duplicates: D-5716
# No duplicates: D-5721
# No duplicates: D-5733
# No duplicates: D-5761
# No duplicates: D-5780
# No duplicates: D-5807
# No duplicates: D-5810
# No duplicates: D-5813
# No duplicates: D-5856
# No duplicates: D-5862
# No duplicates: D-5867
# No duplicates: D-5872
# No duplicates: D-5892
# No duplicates: D-5913
# No duplicates: D-5942
# No duplicates: D-5976
# No duplicates: D-5981
# No duplicates: D-5987
# No duplicates: D-6006
# starting selection on D-6030
# No duplicates: D-6030
# No duplicates: D-6030
# starting selection on D-6041
# No duplicates: D-6041
# No duplicates: D-6041
# No duplicates: D-6054
# No duplicates: D-6088
# No duplicates: D-6109
# No duplicates: D-6110
# No duplicates: D-6120
# No duplicates: D-6125
# No duplicates: D-6126
# No duplicates: D-6127
# No duplicates: D-6158
# No duplicates: D-6188
# No duplicates: D-6246
# No duplicates: D-6267
# No duplicates: D-6269
# No duplicates: D-6280
# No duplicates: D-6286
# No duplicates: D-6292
# No duplicates: D-6303
# No duplicates: D-6320
# No duplicates: D-6348
# No duplicates: D-6385
# No duplicates: D-6394
# No duplicates: D-6410
# No duplicates: D-6443
# No duplicates: D-6463
# No duplicates: D-6471
# No duplicates: D-6480
# No duplicates: D-6484
# No duplicates: D-6485
# No duplicates: D-6521
# No duplicates: D-6523
# No duplicates: D-6524
# No duplicates: D-6545
# No duplicates: D-6561
# No duplicates: D-6562
# No duplicates: D-6566
# No duplicates: D-6580
# No duplicates: D-6626
# No duplicates: D-6643
# No duplicates: D-6646
# No duplicates: D-6647
# No duplicates: D-6695
# No duplicates: D-6697
# No duplicates: D-6705
# No duplicates: D-6768
# No duplicates: D-6793
# No duplicates: D-6812
# No duplicates: D-6824
# No duplicates: D-6826
# No duplicates: D-6827
# No duplicates: D-6832
# starting selection on D-6835
# No duplicates: D-6835
# No duplicates: D-6835
# No duplicates: D-6838
# No duplicates: D-6840
# No duplicates: D-6884
# No duplicates: D-6894
# No duplicates: D-6895
# No duplicates: D-6971
# No duplicates: D-6991
# No duplicates: D-7016
# No duplicates: D-7021
# No duplicates: D-7026
# No duplicates: D-7035
# No duplicates: D-7044
# No duplicates: D-7055
# No duplicates: D-7067
# No duplicates: D-7102
# No duplicates: D-7103
# No duplicates: D-7111
# No duplicates: D-7113
# No duplicates: D-7124
# No duplicates: D-7239
# No duplicates: D-7241
# No duplicates: D-7256
# No duplicates: D-7304
# No duplicates: D-7340
# No duplicates: D-7363
# No duplicates: D-7364
# No duplicates: D-7392
# No duplicates: D-7395
# No duplicates: D-7406
# No duplicates: D-7416
# No duplicates: D-7425
# No duplicates: D-7442
# No duplicates: D-7474
# No duplicates: D-7479
# No duplicates: D-7499
# No duplicates: D-7500
# No duplicates: D-7545
# No duplicates: D-7603
# No duplicates: D-7606
# No duplicates: D-7643
# starting selection on D-7698
# No duplicates: D-7698
# No duplicates: D-7698
# No duplicates: D-7735
# No duplicates: D-7760
# No duplicates: D-7798
# No duplicates: D-7806
# starting selection on D-7819
# No duplicates: D-7819
# No duplicates: D-7819
# No duplicates: D-7820
# No duplicates: D-7825
# No duplicates: D-7826
# No duplicates: D-7878
# No duplicates: D-7879
# No duplicates: D-7890
# starting selection on D-7905
# No duplicates: D-7905
# No duplicates: D-7905
# No duplicates: D-7906
# No duplicates: D-7921
# starting selection on D-7929
# No duplicates: D-7929
# No duplicates: D-7929
# No duplicates: D-7971
# starting selection on D-8011
# No duplicates: D-8011
# No duplicates: D-8011
# No duplicates: D-8012
# No duplicates: D-8014
# No duplicates: D-8064
# No duplicates: D-8089
# No duplicates: D-8099
# No duplicates: D-8101a
# No duplicates: D-8101b
# starting selection on D-8112
# No duplicates: D-8112
# No duplicates: D-8112
# No duplicates: D-8131
# starting selection on D-8132
# No duplicates: D-8132
# No duplicates: D-8132
# No duplicates: D-8133
# No duplicates: D-8134
# No duplicates: D-8135
# No duplicates: D-8136
# No duplicates: D-8137
# No duplicates: D-8138
# No duplicates: D-8139
# No duplicates: D-8140
# No duplicates: D-8141
# No duplicates: D-8142
# No duplicates: D-8143
# No duplicates: D-8144
# No duplicates: D-8145
# No duplicates: D-8146
# No duplicates: D-8147
# No duplicates: D-8198
# No duplicates: D-8235
# No duplicates: D-8301
# No duplicates: D-8303
# No duplicates: D-8308
# No duplicates: D-8330
# No duplicates: D-8331
# No duplicates: D-8333
# No duplicates: D-8351
# No duplicates: D-8363
# No duplicates: D-8390
# starting selection on D-8391
# No duplicates: D-8391
# No duplicates: D-8391
# No duplicates: WH-8496
# No duplicates: D-8529
# No duplicates: D-8588
# No duplicates: D-8592
# No duplicates: D-8600
# No duplicates: D-8612
# No duplicates: D-8632
# No duplicates: D-8635
# No duplicates: D-8697
# No duplicates: D-8708
# No duplicates: D-8726
# No duplicates: D-8728
# No duplicates: D-8734
# No duplicates: D-8769
# No duplicates: D-8770
# No duplicates: D-8802
# No duplicates: D-8839
# No duplicates: D-8867
# No duplicates: D-8881
# No duplicates: D-8921
# No duplicates: D-8970
# starting selection on D-8978
# No duplicates: D-8978
# No duplicates: D-8978
# No duplicates: D-9058
# No duplicates: D-9089
# No duplicates: D-9135
# starting selection on D-9150
# No duplicates: D-9150
# No duplicates: D-9150
# starting selection on D-9153
# No duplicates: D-9153
# No duplicates: D-9153
# No duplicates: D-9156
# No duplicates: D-9183
# No duplicates: D-9185
# starting selection on D-9188
# No duplicates: D-9188
# No duplicates: D-9188
# No duplicates: D-9203
# No duplicates: D-9208
# starting selection on D-9228
# No duplicates: D-9228
# No duplicates: D-9228
# starting selection on D-9237
# No duplicates: D-9237
# No duplicates: D-9237
# starting selection on D-9238
# No duplicates: D-9238
# No duplicates: D-9238
# No duplicates: D-9239
# starting selection on D-9240
# No duplicates: D-9240
# No duplicates: D-9240
# No duplicates: D-9256
# No duplicates: D-9264
# No duplicates: D-9310
# No duplicates: D-9311
# No duplicates: D-9401
# No duplicates: D-9444
# No duplicates: D-9462
# No duplicates: D-9497
# No duplicates: D-9499
# No duplicates: D-9532
# No duplicates: D-9564
# No duplicates: D-9584
# No duplicates: D-9589
# No duplicates: D-9599
# No duplicates: D-9605
# No duplicates: D-9615
# No duplicates: D-9630
# No duplicates: D-9673
# starting selection on D-9677
# No duplicates: D-9677
# No duplicates: D-9677
# No duplicates: WH-9724
# No duplicates: D-9734
# No duplicates: D-9766
# No duplicates: D-9776
# No duplicates: D-9909
# No duplicates: D-9910
# No duplicates: D-9921
# No duplicates: D-9949
# No duplicates: D-10019
# No duplicates: D-10063
# No duplicates: D-10072
# starting selection on D-10074
# No duplicates: D-10074
# No duplicates: D-10074
# No duplicates: D-10079
# No duplicates: D-10104
# No duplicates: D-10154
# No duplicates: D-10261
# No duplicates: D-10268
# No duplicates: D-10279
# No duplicates: D-10293
# No duplicates: D-10306
# No duplicates: D-10327
# No duplicates: D-10415
# No duplicates: D-10457
# No duplicates: D-10474
# No duplicates: D-10487
# No duplicates: D-10493
# No duplicates: D-10512
# No duplicates: D-10539
# No duplicates: D-10545
# No duplicates: D-10556
# No duplicates: D-10590
# No duplicates: D-10616
# No duplicates: D-10633
# No duplicates: D-10711
# No duplicates: D-10724
# No duplicates: D-10728
# No duplicates: D-10729
# No duplicates: D-10730
# No duplicates: D-10743
# starting selection on D-10755
# No duplicates: D-10755
# No duplicates: D-10755
# No duplicates: D-10756
# No duplicates: D-10759
# No duplicates: D-10778
# starting selection on D-10780
# No duplicates: D-10780
# No duplicates: D-10780
# No duplicates: D-10799
# No duplicates: D-10839
# No duplicates: D-10845
# No duplicates: D-10859
# No duplicates: D-10878
# No duplicates: D-10883
# No duplicates: D-10892
# No duplicates: D-10911
# starting selection on D-10924
# No duplicates: D-10924
# No duplicates: D-10924
# No duplicates: D-10938
# No duplicates: D-10939
# No duplicates: D-10940
# No duplicates: D-10941
# No duplicates: D-10946
# No duplicates: D-10950
# starting selection on D-10952
# No duplicates: D-10952
# No duplicates: D-10952
# No duplicates: D-10953
# No duplicates: D-10980
# No duplicates: D-10981
# No duplicates: D-10982
# No duplicates: D-10983
# No duplicates: D-10984
# No duplicates: D-10985
# No duplicates: D-10986
# No duplicates: D-10992
# starting selection on D-10998
# No duplicates: D-10998
# No duplicates: D-10998
# No duplicates: D-11052
# No duplicates: D-11079
# No duplicates: D-11087
# No duplicates: D-11090
# No duplicates: D-11108
# No duplicates: D-11121
# No duplicates: D-11276
# No duplicates: D-11318
# No duplicates: D-11412
# No duplicates: D-11416
# No duplicates: D-11428
# No duplicates: D-11481
# No duplicates: D-11519
# No duplicates: D-11602
# No duplicates: D-11609
# No duplicates: D-11621
# No duplicates: D-11636
# No duplicates: D-11676
# No duplicates: D-11681
# No duplicates: D-11683
# No duplicates: D-11714
# No duplicates: D-11824
# No duplicates: D-11867
# starting selection on D-11868
# No duplicates: D-11868
# No duplicates: D-11868
# No duplicates: D-11949
# No duplicates: D-12012
# No duplicates: D-12019
# starting selection on D-12134
# No duplicates: D-12134
# No duplicates: D-12134
# No duplicates: D-12142
# No duplicates: D-12144
# No duplicates: D-12145
# No duplicates: D-12146
# No duplicates: D-12191
# No duplicates: D-12194
# No duplicates: D-12200
# No duplicates: D-12214
# No duplicates: D-12301
# No duplicates: D-12318
# No duplicates: D-12358
# No duplicates: D-12395
# No duplicates: D-12480
# No duplicates: D-12490
# No duplicates: D-12499
# No duplicates: D-12531
# No duplicates: D-12572
# No duplicates: D-12579
# No duplicates: D-12782
# No duplicates: D-12788
# starting selection on D-12789
# No duplicates: D-12789
# No duplicates: D-12789
# No duplicates: D-12797
# No duplicates: D-12805
# No duplicates: D-12870
# No duplicates: D-12874
# No duplicates: D-12883
# No duplicates: D-12938
# No duplicates: D-12940
# starting selection on D-12951
# No duplicates: D-12951
# No duplicates: D-12951
# No duplicates: D-12957
# starting selection on D-12987
# No duplicates: D-12987
# No duplicates: D-12987
# No duplicates: D-12990
# No duplicates: D-13006
# No duplicates: D-13007
# No duplicates: D-13036
# No duplicates: D-13054
# No duplicates: D-13058
# No duplicates: D-13107
# No duplicates: D-13145
# No duplicates: D-13268
# No duplicates: D-13278
# No duplicates: D-13310
# No duplicates: D-13311
# No duplicates: D-13312
# No duplicates: D-13313
# No duplicates: D-13314
# No duplicates: D-13354
# No duplicates: D-13410
# No duplicates: D-13452
# No duplicates: D-13526
# starting selection on D-13530
# No duplicates: D-13530
# No duplicates: D-13530
# No duplicates: D-13641
# No duplicates: D-13700
# No duplicates: D-13712
# No duplicates: D-13715
# No duplicates: WH-13725
# No duplicates: D-13754
# No duplicates: D-13756
# No duplicates: D-13764
# No duplicates: D-13778
# No duplicates: D-13787
# No duplicates: D-13951
# No duplicates: D-13983
# No duplicates: D-13990
# No duplicates: D-13993
# No duplicates: D-14006
# No duplicates: D-14008
# No duplicates: D-14009
# No duplicates: D-14031
# No duplicates: D-14033
# No duplicates: D-14117
# No duplicates: D-14130
# No duplicates: D-14135
# No duplicates: D-14137
# No duplicates: D-14138
# No duplicates: D-14139
# starting selection on D-14142
# No duplicates: D-14142
# No duplicates: D-14142
# No duplicates: D-14143
# starting selection on D-14147
# No duplicates: D-14147
# No duplicates: D-14147
# starting selection on D-14166
# No duplicates: D-14166
# No duplicates: D-14166
# starting selection on D-14171
# No duplicates: D-14171
# No duplicates: D-14171
# starting selection on D-14175
# No duplicates: D-14175
# No duplicates: D-14175
# No duplicates: D-14185
# No duplicates: D-14187
# No duplicates: D-14190
# No duplicates: WH-14304
# No duplicates: D-14314
# starting selection on D-14321
# No duplicates: D-14321
# No duplicates: D-14321
# No duplicates: D-14350
# No duplicates: D-14351
# No duplicates: D-14390
# No duplicates: D-14416
# No duplicates: D-14417
# No duplicates: D-14429
# No duplicates: D-14467
# No duplicates: D-14471
# No duplicates: D-14481
# starting selection on D-14511
# No duplicates: D-14511
# No duplicates: D-14511
# No duplicates: D-14527
# No duplicates: D-14576
# No duplicates: D-14642
# No duplicates: D-14651
# No duplicates: D-14671
# No duplicates: D-14698
# No duplicates: D-14757
# No duplicates: D-14758
# No duplicates: D-14796
# No duplicates: D-14861
# No duplicates: D-14882
# No duplicates: D-15010
# No duplicates: D-15079
# No duplicates: D-15114
# No duplicates: D-15148
# No duplicates: D-15234
# No duplicates: D-15256
# No duplicates: D-15275
# No duplicates: D-15284
# No duplicates: D-15301
# No duplicates: D-15329
# No duplicates: D-15340
# No duplicates: D-15350
# No duplicates: D-15451
# No duplicates: D-15511
# No duplicates: D-15539
# No duplicates: D-15540
# No duplicates: D-15585
# No duplicates: D-15629
# No duplicates: D-15632
# No duplicates: D-15653
# No duplicates: D-15662
# No duplicates: D-15708
# No duplicates: D-15724
# No duplicates: D-15776
# No duplicates: D-15816
# No duplicates: D-15884
# No duplicates: D-15902
# No duplicates: D-15913
# starting selection on D-15948
# No duplicates: D-15948
# No duplicates: D-15948
# No duplicates: D-16019
# starting selection on D-16024
# No duplicates: D-16024
# No duplicates: D-16024
# No duplicates: D-16025
# No duplicates: D-16026
# No duplicates: D-16090
# No duplicates: D-16104
# No duplicates: D-16129
# No duplicates: WH-16137
# starting selection on D-16178
# No duplicates: D-16178
# No duplicates: D-16178
# No duplicates: D-16205
# No duplicates: D-16292
# No duplicates: D-16342
# No duplicates: D-16368
# No duplicates: D-16473
# No duplicates: D-16511
# No duplicates: D-16534
# No duplicates: D-16560
# No duplicates: D-16561
# No duplicates: D-16607
# No duplicates: D-16636
# No duplicates: D-16678
# No duplicates: D-16788
# No duplicates: D-16790
# starting selection on D-16794
# No duplicates: D-16794
# No duplicates: D-16794
# No duplicates: D-16830
# No duplicates: D-16956
# No duplicates: D-16976
# No duplicates: D-17046
# No duplicates: D-17125
# No duplicates: D-17155
# No duplicates: D-17202
# No duplicates: D-17292
# No duplicates: D-17298
# No duplicates: D-17299
# No duplicates: D-17305
# starting selection on D-17341
# No duplicates: D-17341
# No duplicates: D-17341
# No duplicates: D-17346
# No duplicates: D-17364
# No duplicates: D-17407
# No duplicates: D-17427
# No duplicates: D-17473
# No duplicates: D-17518
# No duplicates: D-17568
# No duplicates: D-17650
# No duplicates: D-17735
# starting selection on D-17806
# No duplicates: D-17806
# No duplicates: D-17806
# No duplicates: D-17886
# No duplicates: D-17890
# No duplicates: D-17892
# No duplicates: D-17904
# No duplicates: D-17951
# No duplicates: D-17956
# No duplicates: D-17962
# No duplicates: D-17992
# No duplicates: D-18158
# No duplicates: D-18207
# No duplicates: D-18210
# No duplicates: D-18212
# No duplicates: D-18214
# No duplicates: D-18216
# No duplicates: D-18218
# No duplicates: D-18280
# No duplicates: D-18367
# No duplicates: D-18424
# No duplicates: D-18441
# No duplicates: D-18474
# No duplicates: D-18533
# No duplicates: D-18562
# starting selection on D-18627
# No duplicates: D-18627
# No duplicates: D-18627
# No duplicates: D-18631
# No duplicates: D-18908
# No duplicates: D-18921
# No duplicates: D-18931
# No duplicates: D-18953
# No duplicates: D-18972
# No duplicates: D-19008
# No duplicates: D-19088
# starting selection on D-19130
# No duplicates: D-19130
# No duplicates: D-19130
# No duplicates: D-19232
# No duplicates: D-19439
# No duplicates: D-19485
# No duplicates: D-19502
# No duplicates: D-19548
# starting selection on D-19562
# No duplicates: D-19562
# No duplicates: D-19562
# No duplicates: D-19586
# No duplicates: D-19615
# No duplicates: D-19654
# No duplicates: D-19658
# No duplicates: D-19719
# No duplicates: D-19726
# No duplicates: D-19745
# No duplicates: D-19753
# No duplicates: D-19778
# No duplicates: D-19833
# No duplicates: D-19909
# No duplicates: D-19949
# No duplicates: D-19952
# No duplicates: D-19959
# No duplicates: D-19969
# No duplicates: D-19971
# No duplicates: D-19979
# No duplicates: D-19984
# No duplicates: D-19994
# starting selection on D-20005
# No duplicates: D-20005
# No duplicates: D-20005
# No duplicates: D-20021
# No duplicates: D-20047
# No duplicates: D-20111
# No duplicates: D-20135
# starting selection on D-20154
# No duplicates: D-20154
# No duplicates: D-20154
# starting selection on D-20185
# No duplicates: D-20185
# No duplicates: D-20185
# No duplicates: D-20229
# No duplicates: D-20274
# No duplicates: D-20289
# No duplicates: D-20338
# No duplicates: D-20348
# No duplicates: D-20364
# No duplicates: D-20401
# No duplicates: D-20422
# No duplicates: D-20443
# No duplicates: D-20449
# No duplicates: D-20489
# No duplicates: D-20541
# No duplicates: D-20542
# No duplicates: D-20623
# No duplicates: D-20649
# No duplicates: D-20691
# No duplicates: D-20697
# No duplicates: D-20714
# No duplicates: D-20721
# No duplicates: D-20739
# No duplicates: D-20765
# No duplicates: D-20771
# No duplicates: D-20831
# No duplicates: D-20832
# No duplicates: D-20882
# No duplicates: D-20927
# No duplicates: D-20942
# No duplicates: D-20965
# No duplicates: D-20966
# No duplicates: D-20985
# No duplicates: D-21023
# No duplicates: D-21066
# No duplicates: D-21096
# No duplicates: D-21117
# No duplicates: D-21120
# No duplicates: D-21182
# No duplicates: D-21196
# No duplicates: D-21205
# No duplicates: D-21397
# No duplicates: D-21425
# No duplicates: D-21460
# No duplicates: D-21511
# No duplicates: D-21584
# No duplicates: D-21647
# No duplicates: D-21671
# No duplicates: D-21673
# No duplicates: D-21746
# starting selection on D-21808
# No duplicates: D-21808
# No duplicates: D-21808
# No duplicates: D-21817
# No duplicates: D-21856
# No duplicates: D-21865
# No duplicates: D-21890
# No duplicates: D-21977
# No duplicates: D-21997
# No duplicates: D-22049
# No duplicates: D-22051
# No duplicates: D-22088
# starting selection on D-22103
# No duplicates: D-22103
# No duplicates: D-22103
# No duplicates: D-22106
# No duplicates: D-22109
# No duplicates: D-22132
# No duplicates: D-22166
# No duplicates: D-22172
# No duplicates: D-22182
# No duplicates: WH-22220
# No duplicates: D-22221
# No duplicates: WH-22319
# No duplicates: WH-22320
# No duplicates: D-22326
# No duplicates: D-22337
# No duplicates: D-22390
# No duplicates: D-22612
# No duplicates: D-22628
# No duplicates: D-22668
# No duplicates: D-22707
# No duplicates: D-22836
# No duplicates: D-22847
# No duplicates: D-22858
# No duplicates: D-22876
# No duplicates: D-22903
# No duplicates: D-22907
# No duplicates: D-22908
# starting selection on D-22933
# No duplicates: D-22933
# No duplicates: D-22933
# No duplicates: D-22964
# No duplicates: D-22999
# No duplicates: D-23024
# No duplicates: D-23063
# No duplicates: D-23074
# No duplicates: D-23092
# No duplicates: D-23104
# No duplicates: D-23110
# No duplicates: D-23188
# No duplicates: D-23204
# No duplicates: D-23252
# No duplicates: D-23264
# No duplicates: D-23277
# No duplicates: D-23282
# No duplicates: D-23310
# No duplicates: D-23313
# No duplicates: D-23325
# No duplicates: D-23351
# No duplicates: D-23466
# No duplicates: D-23707
# No duplicates: D-23721
# No duplicates: D-23730
# No duplicates: D-23812
# No duplicates: D-23874
# No duplicates: D-23892
# No duplicates: D-23947
# No duplicates: D-24081
# No duplicates: D-24087
# No duplicates: D-24096
# starting selection on D-24127
# No duplicates: D-24127
# No duplicates: D-24127
# No duplicates: D-24218
# No duplicates: D-24309
# No duplicates: D-24311
# No duplicates: D-24314
# No duplicates: D-24332
# No duplicates: D-24343
# No duplicates: D-24375
# starting selection on D-24380
# No duplicates: D-24380
# No duplicates: D-24380
# No duplicates: D-24381
# No duplicates: D-24409
# No duplicates: D-24437
# No duplicates: D-24462
# No duplicates: D-24466
# No duplicates: WH-24466
# No duplicates: D-24518
# No duplicates: D-24585
# No duplicates: D-24586
# No duplicates: D-24591
# No duplicates: D-24608
# No duplicates: D-24714
# No duplicates: D-24729
# No duplicates: D-24733
# No duplicates: D-24811
# No duplicates: D-24962
# No duplicates: D-25030
# No duplicates: D-25063
# No duplicates: D-25067
# No duplicates: D-25207
# No duplicates: D-25284
# No duplicates: D-25285
# No duplicates: D-25287
# No duplicates: D-25288
# No duplicates: D-25289
# No duplicates: D-199331
# No duplicates: C-844563
# No duplicates: C-845367
# No duplicates: C-8665101
# No duplicates: WH-12201452
# No duplicates: WH-19707925
# No duplicates: WH-25049904
# No duplicates: WH-25257175
# No duplicates: WH-26456948
# No duplicates: WH-26989237
# No duplicates: WH-29178646
# No duplicates: WH-29406736
# No duplicates: WH-33840546
# No duplicates: WH-33894316
# No duplicates: WH-34514974
# No duplicates: WH-39935935
# No duplicates: WH-43656765
# No duplicates: WH-44496152
# No duplicates: WH-55508885
# No duplicates: WH-56961221
# No duplicates: WH-75142659
# No duplicates: C-86564397
# No duplicates: C-86643201
# No duplicates: WH-114690575
# No duplicates: WH-116545134
# No duplicates: WH-152992187
# No duplicates: WH-176385502
# No duplicates: WH-181965556
# No duplicates: WH-182336607
# No duplicates: WH-261162002
# No duplicates: WH-359236505
# No duplicates: WH-365105604
# No duplicates: WH-389706217
# No duplicates: WH-394496111
# No duplicates: WH-482023151
# No duplicates: WH-502801101
# No duplicates: WH-542089546
# No duplicates: WH-561596765
# No duplicates: C-866500764
# No duplicates: C-866505478
# No duplicates: WH-907734912
# No duplicates: WH-943210460
# No duplicates: WH-1913262020
# No duplicates: WH-2359256119
# No duplicates: WH-2601524623
# No duplicates: WH-2609075040
# No duplicates: WH-2625429206
# No duplicates: WH-2705686573
# No duplicates: WH-2714456838
# No duplicates: WH-2953604840
# No duplicates: WH-3004682262
# No duplicates: WH-3063966541
# No duplicates: WH-3066306967
# No duplicates: C-8664087414
# No duplicates: C-8.67E+13
# No duplicates: WH-5.52E+17
# No duplicates: WH-5.57E+17
# No duplicates: WH-5.67E+17
# No duplicates: WH-5.68E+17
# No duplicates: WH-5.69E+17
# No duplicates: WH-5.70E+17
# No duplicates: WH-5.71E+17
# No duplicates: WH-5.75E+17
# No duplicates: D-0a
# No duplicates: D-1-AP
# No duplicates: D-10-AP
# No duplicates: D-101a
# No duplicates: M-101b
# No duplicates: M-101c
# No duplicates: M-103a
# No duplicates: M-103b
# No duplicates: M-105a
# No duplicates: M-105b
# No duplicates: D-10798a
# No duplicates: D-10798b
# No duplicates: M-109a
# starting selection on M-109b
# No duplicates: M-109b
# No duplicates: M-109b
# No duplicates: M-10a
# starting selection on M-10b
# No duplicates: M-10b
# No duplicates: M-10b
# No duplicates: M-10c
# No duplicates: D-11-AP
# starting selection on D-111a
# No duplicates: D-111a
# No duplicates: D-111a
# No duplicates: M-111b
# No duplicates: M-117a
# No duplicates: M-117b
# No duplicates: M-118a
# No duplicates: M-118b
# No duplicates: M-119a
# No duplicates: M-119b
# No duplicates: M-11a
# No duplicates: M-11b
# No duplicates: M-11c
# No duplicates: M-120a
# No duplicates: M-120b
# No duplicates: M-121a
# No duplicates: M-121b
# No duplicates: D-12283a
# No duplicates: D-12283b
# No duplicates: M-122a
# No duplicates: M-122b
# No duplicates: M-125a
# No duplicates: M-125b
# No duplicates: M-127a
# No duplicates: M-127b
# No duplicates: M-128a
# No duplicates: M-128b
# No duplicates: M-12a
# No duplicates: M-12b
# No duplicates: M-12c
# No duplicates: M-131a
# No duplicates: M-131b
# No duplicates: M-132a
# No duplicates: M-132b
# No duplicates: D-1376a
# starting selection on D-1376b
# No duplicates: D-1376b
# No duplicates: D-1376b
# No duplicates: WH-13857342a
# No duplicates: WH-13857342b
# No duplicates: WH-13857342c
# No duplicates: WH-13857342d
# No duplicates: WH-13857342e
# No duplicates: WH-13857342f
# No duplicates: WH-13857342g
# No duplicates: WH-13857342h
# No duplicates: WH-13857342i
# No duplicates: WH-13857342j
# No duplicates: WH-13857342k
# No duplicates: WH-13857342m
# No duplicates: WH-13857342n
# No duplicates: WH-13857342o
# No duplicates: WH-13857342p
# No duplicates: M-13a
# No duplicates: M-13b
# No duplicates: M-13c
# No duplicates: M-143a
# No duplicates: M-143b
# No duplicates: M-144a
# No duplicates: M-144b
# No duplicates: M-146a
# No duplicates: M-146b
# No duplicates: M-147a
# No duplicates: M-147b
# No duplicates: M-147c
# No duplicates: M-149a
# No duplicates: M-149b
# No duplicates: M-14a
# No duplicates: M-14b
# No duplicates: M-152a
# No duplicates: M-152b
# No duplicates: M-154a
# No duplicates: M-154b
# No duplicates: D-156a
# No duplicates: M-156m
# starting selection on M-158a
# No duplicates: M-158a
# No duplicates: M-158a
# No duplicates: M-158b
# No duplicates: M-158c
# No duplicates: D-159a
# No duplicates: M-159b
# No duplicates: M-159c
# No duplicates: M-15a
# starting selection on M-15b
# No duplicates: M-15b
# No duplicates: M-15b
# No duplicates: M-15c
# No duplicates: WH-1622445516a
# No duplicates: WH-1622445516b
# No duplicates: D-164a
# No duplicates: M-164b
# No duplicates: M-165a
# No duplicates: M-165b
# No duplicates: M-165c
# No duplicates: M-167a
# No duplicates: M-167b
# No duplicates: M-169a
# No duplicates: M-169b
# No duplicates: M-16a
# No duplicates: M-16b
# No duplicates: M-172a
# No duplicates: M-172b
# No duplicates: M-173a
# No duplicates: M-173b
# No duplicates: M-174a
# No duplicates: M-174b
# No duplicates: M-176a
# No duplicates: M-176b
# No duplicates: M-179a
# No duplicates: M-179b
# starting selection on M-17a
# No duplicates: M-17a
# No duplicates: M-17a
# No duplicates: M-17b
# No duplicates: M-17c
# No duplicates: M-17d
# No duplicates: D-1806a
# No duplicates: D-1806b
# No duplicates: M-180a
# No duplicates: M-180b
# No duplicates: M-181a
# No duplicates: M-181b
# No duplicates: M-181c
# No duplicates: M-183a
# No duplicates: M-183b
# No duplicates: M-18a
# No duplicates: M-18b
# No duplicates: M-19a
# starting selection on M-19b
# No duplicates: M-19b
# No duplicates: M-19b
# starting selection on M-1a
# No duplicates: M-1a
# No duplicates: M-1a
# No duplicates: M-1b
# No duplicates: D-2-AP
# No duplicates: M-208a
# No duplicates: M-208b
# No duplicates: M-20a
# No duplicates: M-20b
# No duplicates: M-211a
# No duplicates: M-211b
# No duplicates: M-21a
# No duplicates: M-21b
# No duplicates: D-23348a
# No duplicates: D-23348b
# No duplicates: M-25a
# No duplicates: M-25b
# No duplicates: D-2608a
# No duplicates: D-2608b
# No duplicates: WH-26326439a
# No duplicates: WH-26326439b
# No duplicates: M-26a
# No duplicates: M-26b
# starting selection on WH-2756873076a
# No duplicates: WH-2756873076a
# No duplicates: WH-2756873076a
# No duplicates: WH-2756873076b
# No duplicates: WH-2756873076c
# No duplicates: WH-2941145694a
# No duplicates: WH-2941145694aa
# No duplicates: D-2941145694ab
# No duplicates: WH-2941145694b
# No duplicates: WH-2941145694c
# No duplicates: WH-2941145694d
# No duplicates: WH-2941145694e
# No duplicates: WH-2941145694f
# No duplicates: WH-2941145694g
# No duplicates: WH-2941145694h
# No duplicates: WH-2941145694i
# No duplicates: WH-2941145694j
# No duplicates: WH-2941145694k
# No duplicates: WH-2941145694m
# No duplicates: WH-2941145694n
# No duplicates: WH-2941145694o
# No duplicates: WH-2941145694p
# No duplicates: WH-2941145694q
# No duplicates: WH-2941145694r
# No duplicates: WH-2941145694s
# No duplicates: WH-2941145694t
# No duplicates: WH-2941145694u
# No duplicates: WH-2941145694v
# No duplicates: WH-2941145694w
# No duplicates: WH-2941145694x
# No duplicates: WH-2941145694y
# No duplicates: WH-2941145694z
# No duplicates: M-296a
# No duplicates: M-296b
# No duplicates: M-2a
# No duplicates: M-2b
# No duplicates: D-3-AP
# No duplicates: WH-3041100698a
# No duplicates: WH-3041100698b
# No duplicates: D-3219a
# No duplicates: D-3219b
# No duplicates: D-3223a
# No duplicates: D-3223b
# No duplicates: M-35a
# No duplicates: M-35b
# No duplicates: M-379a
# No duplicates: M-379b
# No duplicates: M-390a
# No duplicates: M-390b
# No duplicates: M-392a
# No duplicates: M-392b
# No duplicates: M-39a
# No duplicates: M-39b
# No duplicates: D-3a
# No duplicates: M-3b
# No duplicates: D-4-AP
# No duplicates: D-4161a
# No duplicates: D-4161b
# No duplicates: M-42a
# No duplicates: M-42b
# No duplicates: M-43a
# No duplicates: M-43b
# starting selection on D-4863a
# No duplicates: D-4863a
# No duplicates: D-4863a
# No duplicates: D-4863b
# No duplicates: D-4906a
# No duplicates: D-4906b
# No duplicates: D-4986a
# No duplicates: D-4986b
# No duplicates: M-4a
# No duplicates: M-4b
# No duplicates: D-5-AP
# No duplicates: M-50a
# starting selection on M-50b
# No duplicates: M-50b
# No duplicates: M-50b
# starting selection on D-535a
# No duplicates: D-535a
# No duplicates: D-535a
# No duplicates: D-535b
# No duplicates: D-535c
# No duplicates: WH-567342000000000000a
# No duplicates: WH-571742000000000000a
# No duplicates: WH-572336000000000000b
# No duplicates: WH-572336000000000000c
# No duplicates: WH-572336000000000000d
# No duplicates: WH-572355000000000000e
# No duplicates: WH-572355000000000000f
# No duplicates: WH-572355000000000000g
# No duplicates: WH-575533000000000000a
# No duplicates: WH-575597000000000000b
# No duplicates: WH-575597000000000000c
# No duplicates: WH-575598000000000000d
# No duplicates: WH-575612000000000000e
# No duplicates: WH-576100000000000000f
# No duplicates: WH-576250000000000000g
# No duplicates: WH-576251000000000000h
# No duplicates: D-5793a
# No duplicates: D-5793b
# No duplicates: M-5a
# No duplicates: M-5b
# No duplicates: M-5c
# No duplicates: D-6-AP
# No duplicates: M-62a
# starting selection on M-62b
# No duplicates: M-62b
# No duplicates: M-62b
# No duplicates: M-65a
# No duplicates: M-65b
# No duplicates: M-681-F
# No duplicates: M-684-F
# No duplicates: M-688-F
# No duplicates: M-690-F
# No duplicates: D-7-AP
# No duplicates: M-7-F
# No duplicates: M-707-F
# No duplicates: M-709-F
# No duplicates: M-713-F
# No duplicates: M-716-F
# No duplicates: M-717-F
# No duplicates: M-718-F
# No duplicates: M-740-F
# No duplicates: M-742-F
# No duplicates: D-7492a
# No duplicates: D-7492b
# No duplicates: M-76-F
# No duplicates: M-761-F
# No duplicates: M-765-F
# No duplicates: D-7a
# No duplicates: D-7b
# No duplicates: D-8-AP
# No duplicates: D-81a
# No duplicates: M-81b
# starting selection on M-82a
# No duplicates: M-82a
# No duplicates: M-82a
# No duplicates: M-82b
# No duplicates: M-83-F
# No duplicates: M-84-F
# No duplicates: D-85a
# No duplicates: M-85b
# starting selection on M-85c
# No duplicates: M-85c
# No duplicates: M-85c
# No duplicates: M-884-F
# starting selection on M-8a
# No duplicates: M-8a
# No duplicates: M-8a
# No duplicates: M-8b
# No duplicates: D-8c
# No duplicates: D-9-AP
# No duplicates: M-9-F
# No duplicates: WH-930620467a
# No duplicates: WH-930620467b
# No duplicates: WH-930620467c
# No duplicates: WH-930620467d
# No duplicates: WH-930620467e
# No duplicates: WH-930620467f
# No duplicates: WH-930620467g
# No duplicates: WH-930620467h
# No duplicates: WH-930620467i
# No duplicates: WH-930620467j
# No duplicates: WH-930620467k
# No duplicates: WH-930620467m
# No duplicates: M-98a
# No duplicates: M-98b
# No duplicates: M-99a

# %%
for x in check_annos.keys():
    print(x, len(check_annos[x]))
# Out:
# 1 2
# 2 127
# 3 1830
# 4 49
# 5 91
# 6 65
# 7 0

# %%
print(len(tweets3), len(tweets2or1), len(tweets4orMore))
# Out:
# 2035 129 205

# %%
for t in tweets3:
    t.getMajVotes()
    t.sort()
    cats[t.cat].append(t.id)

# %%
for c in cats.keys():
    print(c, len(cats[c]))
# Out:
# offSlur 626
# offNom 202
# offDist 20
# offBoth 33
# offOther 78
# reclaimed 399
# nonNom 143
# nonDist 8
# nonBoth 0
# nonNone 526

# %% [markdown]
# ### Create majority vote file

# %%
outfile = "allAnnos_majVote_3per.csv" ### new version, selecting Y when tied
fields = ['ID','DataSet','Text','Off','Slur','Nom','Dist','Cat']
rows = []

for t in tweets3:
    num = len(t.annos)
    thisRow = [t.id, t.dataset, t.text, t.offMaj, t.slurMaj, t.adjNomMaj, t.distMaj, t.cat]

    for x in thisRow[3:7]:
        if x != 'Y' and x != 'N':
            print(x)
            print(thisRow)
            input("okay?")
        else: 
            pass
            
    rows.append(thisRow)

# %%
print(len(rows))
print(rows[:5])
# Out:
# 2035
# [['D-5', 'D', 'You’re black? You don’t sound like you’re black', 'Y', 'N', 'N', 'N', 'offOther'], ['D-6', 'D', 'you’re pretty for a black girl', 'Y', 'N', 'N', 'Y', 'offDist'], ['M-6', 'M', 'eating like A Poor is chic & hilarious bc we are Not Poor & smugly show it', 'Y', 'N', 'Y', 'Y', 'offBoth'], ['C-11', 'C', "I don't think of you as a Mexican", 'Y', 'N', 'N', 'Y', 'offDist'], ['D-13', 'D', '" bad bitches is the only thing that i like "', 'N', 'Y', 'Y', 'N', 'reclaimed']]

# %%
### create file: majority vote annotations for *all* tweets
with open(outfile, 'w') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(fields)
    csvwriter.writerows(rows)

# %% [markdown]
# ### Create agreement files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     474         """
# --> 475         parts = [self.recv(flags, copy=copy, track=track)]
#     476         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.6/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-d5df0069828e> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     236       auth_prompt = d.match.group(1) + '\nEnter your authorization code:\n'
#     237       with open(fifo, 'w') as fifo_file:
# --> 238         fifo_file.write(_getpass.getpass(auth_prompt) + '\n')
#     239       wrote_to_fifo = True
#     240   if not wrote_to_fifo:
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in getpass(self, prompt, stream)
#     685             self._parent_ident,
#     686             self._parent_header,
# --> 687             password=True,
#     688         )
#     689
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
root = "./output"


file3rate = root+"/allAnnos_3ratings_3per.csv"
rows3 = []

fields_base = ["ID", "DataSet", "Text"]
#fields1 = fields_base + ["Off1", "Slur1", "Nom1", "Dist1"]
#fields2 = fields_base + ["Off1", "Off2", "Slur1", "Slur2", "Nom1", "Nom2", "Dist1", "Dist2"]
fields3 = fields_base + ["Off1", "Off2", "Off3", "Slur1", "Slur2", "Slur3","Nom1", "Nom2","Nom3", "Dist1", "Dist2","Dist3"]
#fields4 = fields_base + ["Off1", "Off2", "Off3", "Off4","Slur1", "Slur2", "Slur3","Slur4","Nom1", "Nom2","Nom3", "Nom4","Dist1", "Dist2","Dist3","Dist4"]
#fields5 = fields_base + ["Off1", "Off2", "Off3", "Off4","Off5","Slur1", "Slur2", "Slur3","Slur4","Slur5","Nom1", "Nom2","Nom3", "Nom4","Nom5","Dist1", "Dist2","Dist3","Dist4","Dist5"]
#fields6 = fields_base + ["Off1", "Off2", "Off3", "Off4","Off5","Off6","Slur1", "Slur2", "Slur3","Slur4","Slur5","Slur6","Nom1", "Nom2","Nom3", "Nom4","Nom5","Nom6","Dist1", "Dist2","Dist3","Dist4","Dist5","Dist6"]

# %%
for t in tweets3:
    ratings = len(t.annos)
    if ratings == 3:
        this = [t.id, t.dataset, t.text] + [o for o in t.off] + [s for s in t.slur] + [a for a in t.adjNom] + [d for d in t.dist]
        rows3.append(this)
    else:
        print("error")

# %%
with open(file3rate,'w') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(fields1)
    csvwriter.writerows(rows1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-86f9b33c28be> in <module>()
# ----> 1 with open(file3rate,'w') as csvfile:
#       2     csvwriter = csv.writer(csvfile)
#       3     csvwriter.writerow(fields1)
#       4     csvwriter.writerows(rows1)
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: './output/allAnnos_3ratings_3per.csv'

# %%
with open(file2rate,'w') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(fields2)
    csvwriter.writerows(rows2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-fd4726f600ab> in <module>()
# ----> 1 with open(file2rate,'w') as csvfile:
#       2     csvwriter = csv.writer(csvfile)
#       3     csvwriter.writerow(fields2)
#       4     csvwriter.writerows(rows2)
#       5
#
# NameError: name 'file2rate' is not defined

# %%
with open(file3rate,'w') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(fields3)
    csvwriter.writerows(rows3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-de5dc355b5f6> in <module>()
# ----> 1 with open(file3rate,'w') as csvfile:
#       2     csvwriter = csv.writer(csvfile)
#       3     csvwriter.writerow(fields3)
#       4     csvwriter.writerows(rows3)
#
# FileNotFoundError: [Errno 2] No such file or directory: './output/allAnnos_3ratings_3per.csv'

# %%
with open(file4rate,'w') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(fields4)
    csvwriter.writerows(rows4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-3495f642fdcd> in <module>()
# ----> 1 with open(file4rate,'w') as csvfile:
#       2     csvwriter = csv.writer(csvfile)
#       3     csvwriter.writerow(fields4)
#       4     csvwriter.writerows(rows4)
#
# NameError: name 'file4rate' is not defined

# %%
with open(file5rate,'w') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(fields5)
    csvwriter.writerows(rows5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-87135d8dad87> in <module>()
# ----> 1 with open(file5rate,'w') as csvfile:
#       2     csvwriter = csv.writer(csvfile)
#       3     csvwriter.writerow(fields5)
#       4     csvwriter.writerows(rows5)
#
# NameError: name 'file5rate' is not defined

# %%
with open(file6rate,'w') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(fields6)
    csvwriter.writerows(rows6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-5f643b18c2bd> in <module>()
# ----> 1 with open(file6rate,'w') as csvfile:
#       2     csvwriter = csv.writer(csvfile)
#       3     csvwriter.writerow(fields6)
#       4     csvwriter.writerows(rows6)
#
# NameError: name 'file6rate' is not defined

# %% [markdown]
# ### Sort tweets into categories based on annotations

# %%
gold = []
with open("allAnnos_majVote_3per.csv") as csvfile:
    csvreader = csv.reader(csvfile)
    for row in csvreader:
        gold.append(row)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-25bfe7d1166b> in <module>()
#       1 gold = []
# ----> 2 with open("allAnnos_majVote_3per.csv") as csvfile:
#       3     csvreader = csv.reader(csvfile)
#       4     for row in csvreader:
#       5         gold.append(row)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'allAnnos_majVote_3per.csv'

# %%
def getCat(line):
    cat = ''
    offMaj = line[3]
    slurMaj = line[4]
    adjNomMaj = line[5]
    distMaj = line[6]

    if offMaj == 'Y':
        if slurMaj == 'Y':
            cat = 'offSlur'
        elif adjNomMaj == 'Y':
            if distMaj == 'Y':
                cat = 'offBoth'
            else:
                cat = 'offNom'
        elif distMaj == 'Y':
            cat = 'offDist'
        else:
            cat = 'offOther'
    
    else:
        if slurMaj == 'Y':
            cat = 'reclaimed'
        elif adjNomMaj == 'Y':
            if distMaj == 'Y':
                cat = 'nonBoth'
            else:
                cat = 'nonNom'
        elif distMaj == 'Y':
            cat = 'nonDist'
        else:
            cat = 'nonNone'
    line.append(cat)
    return(line)

# %%
#newgold = []
#for line in gold[1:]:
#    newline = getCat(line)
#    newgold.append(newline)

newgold = [getCat(line) for line in gold[1:]]

# %%
print(len(newgold))
# Out:
# 2035

# %%
fields = ['ID','DataSet','Text','Off','Slur','Nom','Dist','Cat']
with open('allAnnos_majVote_forJordan_withCats.csv','w') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(fields)
    csvwriter.writerows(newgold)

# %% [markdown]
# ### A new approach to agreement

# %%
##  this = [t.id, t.dataset, t.text] + [o for o in t.off] + [s for s in t.slur] + [a for a in t.adjNom] + [d for d in t.dist]

for r in [(rows3,3)]:
    raters = r[1]
    allOff = []
    allSlur = []
    allNom = []
    allDist = []
    for line in r[0]:
        id = line[0]
        allOff += [[str(i), id, line[3+i]] for i in range(raters)]
        allSlur += [[str(i), id, line[4+i]] for i in range(raters)]
        allNom += [[str(i), id, line[5+i]] for i in range(raters)]
        allDist += [[str(i), id, line[6+i]] for i in range(raters)]
    offTask = agreement.AnnotationTask(data=allOff)
    slurTask = agreement.AnnotationTask(data=allSlur)
    nomTask = agreement.AnnotationTask(data=allNom)
    distTask = agreement.AnnotationTask(data=allDist)

    print()
    print("Agreement for tweets with "+str(raters)+" ratings (num="+str(len(r[0]))+"):")
    print("\tFleiss for Off: "+str(offTask.multi_kappa())+"\tAlpha for Off: "+str(offTask.alpha()))
    print("\tFleiss for Slur: "+str(slurTask.multi_kappa())+"\tAlpha for Slur: "+str(slurTask.alpha()))
    print("\tFleiss for AdjNom: "+str(nomTask.multi_kappa())+"\tAlpha for AdjNom: "+str(nomTask.alpha()))
    print("\tFleiss for Dist: "+str(distTask.multi_kappa())+"\tAlpha for Dist: "+str(distTask.alpha()))
    print()
    input("Ready for the next set? ")

#for t in tweets:
 #   ratings = len(t.annos)
 #   if ratings == 1:
 #       pass
 #   elif ratings == 2:
 #       allOff2 = []
 #   offData = [[str(i), t.id, t.off[i]] for i in range(ratings)]   
 #   slurData = [[str(i), t.id, t.slur[i]] for i in range(ratings)]
 #   nomData = [[str(i), t.id, t.adjNom[i]] for i in range(ratings)]
 #   distData = [[t.annos[i], t.id, t.dist[i]] for i in range(ratings)]
 #   if ratings == 3:
 #       allOffData3 += offData
 #       allSlurData3 += slurData
 #       allNomData3 += nomData
 #       allDistData3 += distData
 #   else: pass

#offTask = agreement.AnnotationTask(data=allOffData)
#print("fleiss "+ str(offTask.multi_kappa()))
# Out:
# Agreement for tweets with 3 ratings (num=2035):
# 	Fleiss for Off: 0.612176808641872	Alpha for Off: 0.6115894747296602
# 	Fleiss for Slur: 0.3804445354146634	Alpha for Slur: 0.38006931940131605
# 	Fleiss for AdjNom: 0.4332441798279971	Alpha for AdjNom: 0.4330331965873494
# 	Fleiss for Dist: 0.7530730090496497	Alpha for Dist: 0.7529749285237823
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     474         """
# --> 475         parts = [self.recv(flags, copy=copy, track=track)]
#     476         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.6/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-6738f928fa25> in <module>()
#      24     print("\tFleiss for Dist: "+str(distTask.multi_kappa())+"\tAlpha for Dist: "+str(distTask.alpha()))
#      25     print()
# ---> 26     input("Ready for the next set? ")
#      27
#      28 #for t in tweets:
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %% [markdown]
# ### Analysis of classification results

# %%
deiol = []
results = []

with open('deiol_allAnnos_majVote_3per.csv') as csvfile:
    csvreader = csv.reader(csvfile)
    for row in csvreader:
        deiol.append(row)

with open('results_majVote_dec28_withCats.csv') as csvfile:
    csvreader = csv.reader(csvfile)
    for row in csvreader:
        results.append(row)

print(len(deiol))
print(len(results))
# Out:
# 2036
# 2159

# %%
idsD = []
idsR = []

for x in deiol[1:]:
    idsD.append(x[0])
for x in results[1:]:
    idsR.append(x[0])

print(len(idsD), len(idsR))

rNotD = [x for x in idsR if x not in idsD]
dNotR = [x for x in idsD if x not in idsR]

print(len(rNotD), len(dNotR))
# Out:
# 2035 2158
# 131 19

# %%
wanted = set(idsD) & set(idsR)
print(len(wanted))
# Out:
# 2016

# %%
wantedL = list(wanted)
print(len(wantedL))
# Out:
# 2016

# %%
dresults = []
ids = []
for r in results:
    id = r[0]
    if id in wantedL and id not in ids:
        dresults.append(r)
        ids.append(id)
print(len(dresults))
# Out:
# 2016

# %%
with open('results_deiol_majVote.csv','w') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(deiol[0])
    csvwriter.writerows(dresults)

# %%
import pandas as pd
df = pd.read_csv("test_results.tsv", sep="\t", header=None)
tf = pd.read_csv("pejorative.csv")

# %%
olid_2020_df = pd.concat([tf["ID"], df.idxmax(axis=1)], axis=1)
olid_2020_df[0] = olid_2020_df[0].apply(lambda x: "OFF" if bool(x) else "NOT")

for i in range(len(dresults)):
  ind = dresults[i][0]
  try:
    olid_2020_result = olid_2020_df[olid_2020_df["ID"] == ind][0].values[0]
    dresults[i].append(olid_2020_result)
  except:
    olid_2020_result = olid_2020_df[olid_2020_df["ID"] == ind[:-1]][0].values[0]
    dresults[i].append(olid_2020_result)
    pass

# %% [markdown]
# ### And now some analysis!!!

# %%
### our main file is dresults

hasoc = []
hasoc_binary = []
olid = []
jigsaw = []
olid_2020 = []
### build lists of tuples, where each consists of (category, modelResult)

# %%
# print(dresults[0])
# print(len(dresults))
ind
# Out:
# 'D-6561'

# %%
for line in dresults:
    cat = line[7]
    hasoc.append((cat, line[9]))
    hasoc_binary.append((cat, line[10]))
    olid.append((cat, line[11]))
    jigsaw.append((cat, line[12]))
    olid_2020.append((cat, line[13]))

# %%
olid[0:10]
# Out:
# [('offOther', 'HOF'),
#  ('offDist', 'NOT'),
#  ('offNom', 'NOT'),
#  ('offDist', 'NOT'),
#  ('reclaimed', 'HOF'),
#  ('offDist', 'NOT'),
#  ('nonNom', 'NOT'),
#  ('nonNom', 'NOT'),
#  ('nonNom', 'NOT'),
#  ('offNom', 'HOF')]

# %%
olid_2020[:10]
# Out:
# [('offOther', 'OFF'),
#  ('offDist', 'OFF'),
#  ('offNom', 'OFF'),
#  ('offDist', 'NOT'),
#  ('reclaimed', 'OFF'),
#  ('offDist', 'OFF'),
#  ('nonNom', 'NOT'),
#  ('nonNom', 'NOT'),
#  ('nonNom', 'NOT'),
#  ('offNom', 'OFF')]

# %%
olid[26]
print(len(hasoc), len(hasoc_binary), len(olid), len(jigsaw))
# Out:
# 2016 2016 2016 2016

# %%
def getResultsBinary(pairs, dicto):
    counts = 0
    for p in pairs:
        cat = p[0]
        label = p[1]
        if label == 'NOT':
            dicto[cat][1] += 1
            counts += 1
        elif label == 'HOF' or label == 'OFF' or label == 'TOX':
            dicto[cat][0] += 1
            counts += 1
        else:
            print("label error:", label)
            input("okay? ")
    print(counts)
    print(dicto)

# %%
def getResultsHasoc(pairs, dicto):
    counts = 0
    for p in pairs:
        cat = p[0]
        label = p[1]
        #print(cat, label)
        if label == 'HATE':
            dicto[cat][0] += 1
            counts += 1
        elif label ==  'OFFN' or label == 'OFF':
            dicto[cat][1] += 1
            counts += 1
        elif label == 'PRFN':
            dicto[cat][2] += 1
            counts += 1
        elif label == 'NOT':
            dicto[cat][3] += 1
            counts += 1
        else:
            print("label error:", label)
            input("okay? ")
    print(counts)
    print(dicto)

# %%
### offSlur, offNom, offDist, offBoth, offNone: hasoc-HATE/OFFN/PRFN, hasoc_binary-HOF, olid-HOF, jigsaw-TOX
### reclaimed, nonNom, nonDist, nonBoth, nonNone: hasoc-NOT, hasoc_binary-NOT, olid-NOT, jigsaw-NOT
### binary dictionaries - [OFF, NOT]
### 4part dictionary - [HATE, OFFN, PRFN, NOT]

hasocDict = {}
hasoc_binaryDict = {}
olidDict = {}
jigsawDict = {}
olid_2020_Dict = {}

for k in cats.keys():
    hasocDict[k] = [0,0,0,0]
    hasoc_binaryDict[k] = [0,0]
    olidDict[k] = [0,0]
    jigsawDict[k] = [0,0]
    olid_2020_Dict[k] = [0,0]

# %%
hasocDict
# Out:
# {'nonBoth': [0, 0, 0, 0],
#  'nonDist': [1, 0, 0, 5],
#  'nonNom': [9, 8, 10, 114],
#  'nonNone': [20, 18, 24, 463],
#  'offBoth': [5, 4, 3, 19],
#  'offDist': [6, 5, 2, 6],
#  'offNom': [27, 19, 25, 130],
#  'offOther': [12, 23, 12, 34],
#  'offSlur': [30, 129, 287, 174],
#  'reclaimed': [3, 14, 253, 122]}

# %%
print("running full hasoc")
getResultsHasoc(hasoc, hasocDict)
print("running hasoc binary")
getResultsBinary(hasoc_binary, hasoc_binaryDict)
print("running olid")
getResultsBinary(olid, olidDict)
print("running jigsaw")
getResultsBinary(jigsaw, jigsawDict)
print("running olid_2020")
getResultsBinary(olid, olid_2020_Dict)
# Out:
# running full hasoc
# 2016
# {'offSlur': [30, 129, 287, 174], 'offNom': [27, 19, 25, 130], 'offDist': [6, 5, 2, 6], 'offBoth': [5, 4, 3, 19], 'offOther': [12, 23, 12, 34], 'reclaimed': [3, 14, 253, 122], 'nonNom': [9, 8, 10, 114], 'nonDist': [1, 0, 0, 5], 'nonBoth': [0, 0, 0, 0], 'nonNone': [20, 18, 24, 463]}
# running hasoc binary
# 2016
# {'offSlur': [480, 140], 'offNom': [81, 120], 'offDist': [13, 6], 'offBoth': [14, 17], 'offOther': [60, 21], 'reclaimed': [308, 84], 'nonNom': [48, 93], 'nonDist': [2, 4], 'nonBoth': [0, 0], 'nonNone': [117, 408]}
# running olid
# 2016
# {'offSlur': [529, 91], 'offNom': [128, 73], 'offDist': [13, 6], 'offBoth': [23, 8], 'offOther': [64, 17], 'reclaimed': [310, 82], 'nonNom': [61, 80], 'nonDist': [4, 2], 'nonBoth': [0, 0], 'nonNone': [142, 383]}
# running jigsaw
# 2016
# {'offSlur': [547, 73], 'offNom': [80, 121], 'offDist': [12, 7], 'offBoth': [7, 24], 'offOther': [62, 19], 'reclaimed': [337, 55], 'nonNom': [40, 101], 'nonDist': [3, 3], 'nonBoth': [0, 0], 'nonNone': [104, 421]}
# running olid_2020
# 2016
# {'offSlur': [540, 80], 'offNom': [119, 82], 'offDist': [15, 4], 'offBoth': [22, 9], 'offOther': [65, 16], 'reclaimed': [324, 68], 'nonNom': [50, 91], 'nonDist': [4, 2], 'nonBoth': [0, 0], 'nonNone': [148, 377]}

# %%
def printPerc(dicto):
    for k in dicto.keys():
        print(k)
        total = sum(dicto[k])
        if total == 0:
            print("no instances")
            print()
            continue
        for n in dicto[k]:
            print(n/total, sep="\t")
        print()

# %%
printPerc(hasocDict)
# Out:
# offSlur
# 0.04838709677419355
# 0.20806451612903226
# 0.4629032258064516
# 0.2806451612903226
#
# offNom
# 0.13432835820895522
# 0.0945273631840796
# 0.12437810945273632
# 0.6467661691542289
#
# offDist
# 0.3157894736842105
# 0.2631578947368421
# 0.10526315789473684
# 0.3157894736842105
#
# offBoth
# 0.16129032258064516
# 0.12903225806451613
# 0.0967741935483871
# 0.6129032258064516
#
# offOther
# 0.14814814814814814
# 0.2839506172839506
# 0.14814814814814814
# 0.41975308641975306
#
# reclaimed
# 0.007653061224489796
# 0.03571428571428571
# 0.6454081632653061
# 0.3112244897959184
#
# nonNom
# 0.06382978723404255
# 0.05673758865248227
# 0.07092198581560284
# 0.8085106382978723
#
# nonDist
# 0.16666666666666666
# 0.0
# 0.0
# 0.8333333333333334
#
# nonBoth
# no instances
#
# nonNone
# 0.0380952380952381
# 0.03428571428571429
# 0.045714285714285714
# 0.8819047619047619

# %%
printPerc(hasoc_binaryDict)
# Out:
# offSlur
# 0.7741935483870968
# 0.22580645161290322
#
# offNom
# 0.40298507462686567
# 0.5970149253731343
#
# offDist
# 0.6842105263157895
# 0.3157894736842105
#
# offBoth
# 0.45161290322580644
# 0.5483870967741935
#
# offOther
# 0.7407407407407407
# 0.25925925925925924
#
# reclaimed
# 0.7857142857142857
# 0.21428571428571427
#
# nonNom
# 0.3404255319148936
# 0.6595744680851063
#
# nonDist
# 0.3333333333333333
# 0.6666666666666666
#
# nonBoth
# no instances
#
# nonNone
# 0.22285714285714286
# 0.7771428571428571

# %%
printPerc(olidDict)
# Out:
# offSlur
# 0.853225806451613
# 0.14677419354838708
#
# offNom
# 0.6368159203980099
# 0.36318407960199006
#
# offDist
# 0.6842105263157895
# 0.3157894736842105
#
# offBoth
# 0.7419354838709677
# 0.25806451612903225
#
# offOther
# 0.7901234567901234
# 0.20987654320987653
#
# reclaimed
# 0.7908163265306123
# 0.20918367346938777
#
# nonNom
# 0.4326241134751773
# 0.5673758865248227
#
# nonDist
# 0.6666666666666666
# 0.3333333333333333
#
# nonBoth
# no instances
#
# nonNone
# 0.2704761904761905
# 0.7295238095238096

# %%
printPerc(jigsawDict)
# Out:
# offSlur
# 0.882258064516129
# 0.11774193548387096
#
# offNom
# 0.39800995024875624
# 0.6019900497512438
#
# offDist
# 0.631578947368421
# 0.3684210526315789
#
# offBoth
# 0.22580645161290322
# 0.7741935483870968
#
# offOther
# 0.7654320987654321
# 0.2345679012345679
#
# reclaimed
# 0.8596938775510204
# 0.14030612244897958
#
# nonNom
# 0.28368794326241137
# 0.7163120567375887
#
# nonDist
# 0.5
# 0.5
#
# nonBoth
# no instances
#
# nonNone
# 0.1980952380952381
# 0.8019047619047619

# %%
printPerc(olid_2020_Dict)
# Out:
# offSlur
# 0.8709677419354839
# 0.12903225806451613
#
# offNom
# 0.5920398009950248
# 0.4079601990049751
#
# offDist
# 0.7894736842105263
# 0.21052631578947367
#
# offBoth
# 0.7096774193548387
# 0.2903225806451613
#
# offOther
# 0.8024691358024691
# 0.19753086419753085
#
# reclaimed
# 0.826530612244898
# 0.17346938775510204
#
# nonNom
# 0.3546099290780142
# 0.6453900709219859
#
# nonDist
# 0.6666666666666666
# 0.3333333333333333
#
# nonBoth
# no instances
#
# nonNone
# 0.2819047619047619
# 0.7180952380952381
